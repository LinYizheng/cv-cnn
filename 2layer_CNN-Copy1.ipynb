# %%
#cifar-10-test
import numpy as np
import pandas as pd
import scipy
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import StandardScaler

from sklearn import metrics
from hyperopt import hp, fmin, tpe, hp, STATUS_OK, Trials,rand
from hyperopt.mongoexp import MongoTrials
import h5py
from sklearn.model_selection import RandomizedSearchCV,GridSearchCV,train_test_split
from time import time
import matplotlib.pyplot as plt
from sqlalchemy import *
from sqlalchemy.engine import create_engine
from sqlalchemy.schema import *
from sklearn import svm,preprocessing
import time
from pyhive import hive
import sasl
import thrift
import thrift_sasl
from sklearn.externals import joblib
import xgboost as xgb
#from sklearn.ensemble import AdaBoostClassifier,GradientBoostingClassifier,RandomForestClassifier
import tensorflow as tf
import sobol
import datetime
import os
import math
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function
import argparse
import datetime 
import sys
import tensorflow as tf
import numpy as np
import time
from pyDOE import *
from sklearn.decomposition import PCA
import cv2
# Out:
# /usr/lib64/python2.7/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
def readData(pairpathlabel):
    '''read image to list'''
    imgs = []
    labels = []
    for filepath, label in pairpathlabel:
        for (path,dirnames,filenames) in os.walk(filepath):
            print(path)
            for filename in filenames:
                print(filename)
                if filename.endswith('.jpg') or filename.endswith('.PNG'):
                    img_path=path+'/'+filename
                    img=cv2.imread(img_path,0)
                    #img=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
                    imgs.append(img)
                    labels.append(label)
    return np.array(imgs), np.array(labels)
def onehot(numlist):
    ''' get one hot return host matrix is len * max+1 demensions'''
    b = np.zeros([len(numlist), max(numlist)+1])
    b[np.arange(len(numlist)), numlist] = 1
    return b.tolist()

def getfileandlabel(filedir):
    ''' get path and host paire and class index to name'''
    dictdir = dict([[name, os.path.join(filedir, name)] \
                    for name in os.listdir(filedir) 
                    if os.path.isdir(os.path.join(filedir, name)) and not name.startswith('.')])
                    #for (path, dirnames, _) in os.walk(filedir) for dirname in dirnames])
    dirnamelist, dirpathlist = dictdir.keys(), dictdir.values()
    indexlist = list(range(len(dirnamelist)))
    return list(zip(dirpathlist, (indexlist))), dict(zip(indexlist, dirnamelist))
    
pathlabelpair, indextoname = getfileandlabel('images')
x, y = readData(pathlabelpair)
print(np.array(x).shape,y.shape)
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=.5,stratify =y, random_state=0)

imgs=[]
labels=[]
size=90
for (img,label) in zip(X_train,y_train):
    rows,cols = img.shape[:2]
    for i in range(rows-size):
        for j in range(cols-size):
            imgs.append(img[i:i+size,j:j+size])
            labels.append(label)
            imgs.append(cv2.flip(img[i:i+size,j:j+size],1))
            labels.append(label)
            imgs.append(cv2.flip(img[i:i+size,j:j+size],0))
            labels.append(label)
            imgs.append(cv2.flip(img[i:i+size,j:j+size],-1))  
            labels.append(label)
            clahe = cv2.createCLAHE(clipLimit=2.0,tileGridSize=(8,8))
            imgs.append(clahe.apply(img[i:i+size,j:j+size]))
            labels.append(label)
            imgs.append(clahe.apply(cv2.flip(img[i:i+size,j:j+size],1)))
            labels.append(label)
            imgs.append(clahe.apply(cv2.flip(img[i:i+size,j:j+size],0)))
            labels.append(label)
            imgs.append(clahe.apply(cv2.flip(img[i:i+size,j:j+size],-1)))
            labels.append(label)
            

    print(np.array(imgs).shape,"+++",np.array(labels).shape)
imgs=np.array(imgs).tolist()
labels=np.array(labels)
X_train, X_val, y_train, y_val = train_test_split(imgs,labels, test_size=.3,stratify =labels, random_state=0)
         
te_imgs_1=[]
te_labels_1=[]
te_imgs_h1=[]
te_labels_h1=[]
te_imgs_v1=[]
te_labels_v1=[]
te_imgs_hv1=[]
te_labels_hv1=[]
te_imgs_2=[]
te_labels_2=[]
te_imgs_h2=[]
te_labels_h2=[]
te_imgs_v2=[]
te_labels_v2=[]
te_imgs_hv2=[]
te_labels_hv2=[]
te_imgs_3=[]
te_labels_3=[]
te_imgs_h3=[]
te_labels_h3=[]
te_imgs_v3=[]
te_labels_v3=[]
te_imgs_hv3=[]
te_labels_hv3=[]
te_imgs_4=[]
te_labels_4=[]
te_imgs_h4=[]
te_labels_h4=[]
te_imgs_v4=[]
te_labels_v4=[]
te_imgs_hv4=[]
te_labels_hv4=[]
te_imgs_5=[]
te_labels_5=[]
te_imgs_h5=[]
te_labels_h5=[]
te_imgs_v5=[]
te_labels_v5=[]
te_imgs_hv5=[]
te_labels_hv5=[]

size=90
for (img,label) in zip(X_test,y_test):  
    h,w = img.shape[:2]
    label=label-1
    for i in range(1,6):                            
        if i==1:
            te_imgs_1.append(img[0:size,0:size])
            te_labels_1.append(label)
            te_imgs_h1.append(cv2.flip(img[0:size,0:size],1))
            te_labels_h1.append(label)
            te_imgs_v1.append(cv2.flip(img[0:size,0:size],0))
            te_labels_v1.append(label)
            te_imgs_hv1.append(cv2.flip(img[0:size,0:size],-1)) 
            te_labels_hv1.append(label)
        elif i==2:
            te_imgs_2.append(img[h-size:h,0:size])
            te_labels_2.append(label)
            te_imgs_h2.append(cv2.flip(img[h-size:h,0:size],1))
            te_labels_h2.append(label)
            te_imgs_v2.append(cv2.flip(img[h-size:h,0:size],0))
            te_labels_v2.append(label)
            te_imgs_hv2.append(cv2.flip(img[h-size:h,0:size],-1))  
            te_labels_hv2.append(label)
        elif i==3:
            te_imgs_3.append(img[h-size:h,w-size:w])
            te_labels_3.append(label)
            te_imgs_h3.append(cv2.flip(img[h-size:h,w-size:w],1))
            te_labels_h3.append(label)
            te_imgs_v3.append(cv2.flip(img[h-size:h,w-size:w],0))
            te_labels_v3.append(label)
            te_imgs_hv3.append(cv2.flip(img[h-size:h,w-size:w],-1)) 
            te_labels_hv3.append(label)
        elif i==4:
            te_imgs_4.append(img[0:size,w-size:w])
            te_labels_4.append(label)
            te_imgs_h4.append(cv2.flip(img[0:size,w-size:w],1))
            te_labels_h4.append(label)
            te_imgs_v4.append(cv2.flip(img[0:size,w-size:w],0))
            te_labels_v4.append(label)
            te_imgs_hv4.append(cv2.flip(img[0:size,w-size:w],-1)) 
            te_labels_hv4.append(label)
        else :
            hs=(h-size)//2
            ws=(w-size)//2
            te_imgs_5.append(img[hs:hs+size,ws:ws+size])
            te_labels_5.append(label)
            te_imgs_h5.append(cv2.flip(img[hs:hs+size,ws:ws+size],1))
            te_labels_h5.append(label)
            te_imgs_v5.append(cv2.flip(img[hs:hs+size,ws:ws+size],0))
            te_labels_v5.append(label)
            te_imgs_hv5.append(cv2.flip(img[hs:hs+size,ws:ws+size],-1)) 
            te_labels_hv5.append(label)
# Out:
# images/cluster
# defect_test1.PNG
# defect_test.PNG
# images/ball
# defect_test21.PNG
# defect_test2.PNG
# (4,) (4,)
# (192, 90, 90) +++ (192,)
# (1512, 90, 90) +++ (1512,)

# %%
#卷积函数
def conv_bn_pool( x, conv_size, channels, out_channels,cstride_size, wb_initializer, activation,pool_type,pool_size,pstride_size, is_training):
    # Create variable named "weights".
    #initializer = tf.random_uniform_initializer(-0.01, 0.01)
    kernel_shape, bias_shape = [conv_size,conv_size,channels,out_channels],[out_channels]
    weights = tf.get_variable(
        name='conv_weights', shape=kernel_shape,initializer=wb_initializer)

    # Create variable named "biases".
    biases = tf.get_variable(
        name='conv_bias', shape=bias_shape,initializer=wb_initializer)
    conv = tf.nn.conv2d(
        x, weights, strides=[1, cstride_size, cstride_size, 1], padding='SAME')
    z = conv + biases
    bn = batch_normalization(z,is_training)
    relu = activation(bn)
    if pool_type != None:
        pool = pool_type(
            relu, ksize=[1, pool_size, pool_size, 1],strides=[1, pstride_size, pstride_size, 1], padding='SAME')

    return pool


def batch_normalization(x,is_training):
    '''
    Realize batch normalization
    '''
    x_shape = x.get_shape()
    params_shape = x_shape[-1]
    axis = list(range(len(x_shape) - 1))
    #The bias for batch normalization
    beta = tf.get_variable(
        name='beta',shape=params_shape,initializer=tf.zeros_initializer)
    #The scale of batch normalization
    gamma = tf.get_variable(
        name='gamma',shape=params_shape,initializer=tf.ones_initializer)
    #Record moving average for testing
    moving_mean = tf.get_variable(
        name='moving_mean',shape=params_shape,initializer=tf.zeros_initializer,trainable=False)
    #Record moving average for testing
    moving_variance = tf.get_variable(
        name='moving_variance',shape=params_shape,initializer=tf.ones_initializer,trainable=False)  
    # These ops will only be preformed when training.
    mean, variance = tf.nn.moments(x, axis)
    #Update moving averages
    decay = 0.95
    update_moving_mean = tf.assign(moving_mean,moving_mean * decay + mean * (1 - decay))
    update_moving_variance = tf.assign(moving_variance,moving_variance * decay + variance * (1 - decay))


    if is_training=='True':
        x = tf.nn.batch_normalization(x, mean, variance, beta, gamma, 0.001)
    else:
        with tf.control_dependencies([update_moving_mean, update_moving_variance]):
            x = tf.nn.batch_normalization(x, moving_mean, moving_variance, beta, gamma, 0.001) 

    return x

initializers = [tf.constant_initializer(0),tf.truncated_normal_initializer(0,0.1),tf.random_normal_initializer(0,0.1),
                                       tf.random_uniform_initializer(-0.1,0.1),tf.uniform_unit_scaling_initializer(),
                                       tf.glorot_uniform_initializer(),tf.glorot_normal_initializer()]
activations = [tf.nn.sigmoid,tf.nn.tanh,tf.nn.relu,tf.nn.softplus,tf.nn.elu,tf.nn.selu,tf.nn.relu6]
optimizers = ['Adam','GradientDescend','Adagrad','Momentum','Ftrl','RMSProp']

space = {
    'conv_size1': hp.choice('conv_size1',range(3,8)),
    'out_channels1': hp.choice('out_channels1',range(10,201)),                
    'cstride_size1': hp.choice('cstride_size1',range(2,4)),
    'wb_initializer1': hp.choice('wb_initializer1',initializers),
    'activation1': hp.choice('activation1', activations),
    'pool_type1': hp.choice('pool_type1',[tf.nn.max_pool,tf.nn.avg_pool]),                    
    'pool_size1': hp.choice('pool_size1', range(2,4)),                      
    'pstride_size1': hp.choice('pstride_size1',range(1,3)), 

    'conv_size2': hp.choice('conv_size2', range(3,8)),
    'out_channels2': hp.choice('out_channels2',range(10,201)),                
    'cstride_size2': hp.choice('cstride_size2',range(1,3)),
    'wb_initializer2': hp.choice('wb_initializer2',initializers),
    'activation2': hp.choice('activation2', activations),
    'pool_type2': hp.choice('pool_type2',[tf.nn.max_pool,tf.nn.avg_pool]),                    
    'pool_size2': hp.choice('pool_size2',range(2,4)),                      
    'pstride_size2': hp.choice('pstride_size2',range(1,3)),  
    
    'fc_nodes1': hp.choice('fc_nodes1', range(10,2049)),   
    'fc_initializer1': hp.choice('fc_initializer1',initializers),
    'fc_activation1': hp.choice('fc_activation1', activations),
    'keep_prob1': hp.uniform('keep_prob1', 0,1),
    
    'fc_initializer2': hp.choice('fc_initializer2',initializers),

    'optimizer': hp.choice('optimizer',optimizers),
    'batch_size' : hp.choice('batch_size', range(28,256)),
    'learning_rate': hp.uniform('learning_rate', 0.0001,0.1)

        }


def cnn(params):
    print (time.strftime("%Y-%m-%d %H:%M:%S",time.localtime()))
    tf.reset_default_graph()
    image_holder = tf.placeholder(tf.float32, [None,90,90])
    label_holder = tf.placeholder(tf.int32, [None]) 
    is_training = tf.placeholder(tf.string) 
    x_image = tf.reshape(image_holder, [-1,90,90,1])

    #First Conv
    with tf.variable_scope('hidden1'):
        h_pool1 = conv_bn_pool(x = x_image,conv_size = params['conv_size1'],channels = 1, 
                                    out_channels = params['out_channels1'],cstride_size = params['cstride_size1'],
                                    wb_initializer = params['wb_initializer1'],activation = params['activation1'],
                                    pool_type = params['pool_type1'],pool_size = params['pool_size1'],
                                    pstride_size = params['pstride_size1'],is_training = is_training)
        #Second variable_scope
    with tf.variable_scope('hidden2'):
        h_pool2 = conv_bn_pool(x = h_pool1,conv_size = params['conv_size2'],channels = params['out_channels1'], 
                                    out_channels = params['out_channels2'],cstride_size = params['cstride_size2'],
                                    wb_initializer = params['wb_initializer2'],activation = params['activation2'],
                                    pool_type = params['pool_type2'],pool_size = params['pool_size2'],
                                    pstride_size = params['pstride_size2'],is_training = is_training)

    #Fully Connected Layer
    with tf.variable_scope('fully_conn1'):
        h_pool2_flat = tf.reshape(h_pool2, [-1, np.prod(h_pool2.shape[1:])])
        W_fc1 = tf.get_variable(
            name='weights1', shape=[np.prod(h_pool2.shape[1:]), params['fc_nodes1']],
            initializer=params['fc_initializer1'])
        b_fc1 = tf.get_variable(name='bias1', shape=[params['fc_nodes1']],initializer=params['fc_initializer1'])
        
        h_fc1 = params['fc_activation1'](
            batch_normalization(tf.matmul(h_pool2_flat, W_fc1) + b_fc1,is_training)) 
        h_fc1_drop = tf.nn.dropout(h_fc1, params['keep_prob1'])
        
    #Softmax Layer
    with tf.variable_scope('softmax_layers'):
        W_fc2 = tf.get_variable(name='weights2', shape=[params['fc_nodes1'], 10],initializer=params['fc_initializer2'])
        b_fc2 = tf.get_variable(name='bias2', shape=[10],initializer=params['fc_initializer2'])
        logits = tf.matmul(h_fc1_drop, W_fc2) + b_fc2

    cross_entropy = tf.losses.sparse_softmax_cross_entropy(labels=label_holder, logits=logits)
    loss = tf.reduce_mean(cross_entropy)

    global_step=tf.Variable(0)
    lr=tf.train.exponential_decay(params['learning_rate'],global_step,10,0.95,staircase=True)
    if params['optimizer']=='Adam':
        train_op = tf.train.AdamOptimizer(lr).minimize(loss)
    elif params['optimizer']=='GradientDescend':
        train_op = tf.train.GradientDescentOptimizer(lr).minimize(loss)
    elif params['optimizer']=='Adagrad':
        train_op = tf.train.AdagradOptimizer(0.01).minimize(loss)            
    elif params['optimizer']=='Momentum':
        train_op = tf.train.MomentumOptimizer(lr,0.25).minimize(loss)
    elif params['optimizer']=='Ftrl':
        train_op = tf.train.FtrlOptimizer(lr).minimize(loss)            
    else :
        train_op = tf.train.RMSPropOptimizer(lr).minimize(loss)  
    
    top_k_op = tf.nn.in_top_k(logits, label_holder, 1)
    
    print(params)
    epochs = 15
    train_num_examples=y_train.shape[0]
    max_steps = int(math.ceil(train_num_examples / (params['batch_size']+0.0)))
    total_sample_train = max_steps * params['batch_size']
    best = 0
    wait = 0  #counter for patience
    best_rounds =1
    counter=0
    patience=2
    train_acc_all=[]

    min_fraction_of_examples_in_queue = 0.4
    min_queue_examples = int(y_train.shape[0] * min_fraction_of_examples_in_queue)
    input_queue=tf.train.slice_input_producer([X_train,y_train],shuffle=False)
    X_batch,y_batch = tf.train.batch(input_queue,batch_size=params['batch_size'],num_threads=40,capacity=min_queue_examples + 3 * params['batch_size'])  
    # 定义会话并开始迭代训练
    sess = tf.InteractiveSession()
    tf.global_variables_initializer().run()
    # 启动图片数据增强的线程队列
    coord = tf.train.Coordinator()
    threads = tf.train.start_queue_runners(coord=coord)
    for epoch in range(epochs):
        #print ("epoch--:%d"%(epoch+1))        
        true_count_train = 0
        for step in range(max_steps):
            image_batch, label_batch = sess.run([X_batch,y_batch])
            feed_dict ={image_holder: image_batch,label_holder: label_batch, is_training: 'True'}
            #Train
            _, l, a = sess.run([train_op, loss,top_k_op],feed_dict=feed_dict)
            '''if step%100 == 0:
                print('Batch_size:',params['batch_size'], 'Train Batch Accuracy:',np.sum(a)/ params['batch_size'],'step:',step+1)'''
            
            true_count_train += np.sum(a)
        train_accuracy = true_count_train / total_sample_train
        train_acc_all.append(train_accuracy)

        accuracy = sess.run([top_k_op],feed_dict={image_holder: X_val,label_holder: y_val, is_training: 'False'})
        true_count = np.sum(accuracy)
        current_accuracy = true_count / y_val.shape[0]
        counter +=1

        if current_accuracy >= best:
            best = current_accuracy
            best_rounds=counter
            wait = 0
        else:
            wait += 1 #incremental the number of times without improvement
            if wait >= patience : #no more patience, retrieve best model
                break
    print ("epoch--:%d"%(epoch+1))
    print('Best number of rounds: %d , best_val_precision: %f ,best_train_accuracy: %f' % (best_rounds, best,train_acc_all[best_rounds-1]))
    coord.request_stop()
    coord.join(threads)
    sess.close()        
    return {'loss': current_accuracy*(-1),'val_accuracy':best,'train_accuracy':train_acc_all[best_rounds-1],'best_rounds':best_rounds,'status': STATUS_OK}


print (time.strftime("%Y-%m-%d %H:%M:%S",time.localtime()))
max_evals=50
doe_num=30
trials = Trials()
best =  fmin(cnn, space, algo=tpe.suggest, trials=trials, verbose=0, max_evals=max_evals, doe_num=doe_num)
print ("best:",best)
print (trials.best_trial)
print (time.strftime("%Y-%m-%d %H:%M:%S",time.localtime()))
# Out:
# 2018-09-28 11:11:28
# 2018-09-28 11:11:31
# {'fc_nodes1': 138, 'optimizer': 'GradientDescend', 'pool_size1': 3, 'pool_size2': 3, 'cstride_size1': 3, 'batch_size': 221, 'cstride_size2': 2, 'pool_type1': <function avg_pool at 0x941b9b0>, 'conv_size1': 5, 'conv_size2': 7, 'pool_type2': <function avg_pool at 0x941b9b0>, 'pstride_size2': 1, 'pstride_size1': 2, 'fc_initializer2': <tensorflow.python.ops.init_ops.RandomUniform object at 0xc19f790>, 'fc_initializer1': <tensorflow.python.ops.init_ops.VarianceScaling object at 0xc19f850>, 'learning_rate': 0.08270355800673833, 'keep_prob1': 0.040277308390250455, 'fc_activation1': <function softplus at 0x8ad7410>, 'activation2': <function elu at 0x8a6cc08>, 'activation1': <function relu at 0x8ac6938>, 'wb_initializer1': <tensorflow.python.ops.init_ops.RandomUniform object at 0xc19f790>, 'out_channels1': 190, 'out_channels2': 41, 'wb_initializer2': <tensorflow.python.ops.init_ops.RandomUniform object at 0xc19f790>}
# /usr/lib/python2.7/site-packages/tensorflow/python/client/session.py:1711: UserWarning: An interactive session is already active. This can cause out-of-memory errors in some cases. You must explicitly call `InteractiveSession.close()` to release resources held by the other session(s).
#   warnings.warn('An interactive session is already active. This can '
# epoch--:9
# Best number of rounds: 6 , best_val_precision: 0.863436 ,best_train_accuracy: 0.800905
# 2018-09-28 11:12:56
# {'fc_nodes1': 1452, 'optimizer': 'Adagrad', 'pool_size1': 3, 'pool_size2': 2, 'cstride_size1': 2, 'batch_size': 165, 'cstride_size2': 1, 'pool_type1': <function max_pool at 0x941ba28>, 'conv_size1': 6, 'conv_size2': 7, 'pool_type2': <function avg_pool at 0x941b9b0>, 'pstride_size2': 1, 'pstride_size1': 2, 'fc_initializer2': <tensorflow.python.ops.init_ops.RandomUniform object at 0xc19f790>, 'fc_initializer1': <tensorflow.python.ops.init_ops.RandomNormal object at 0xc19f750>, 'learning_rate': 0.0724362459961808, 'keep_prob1': 0.9759144277139743, 'fc_activation1': <function selu at 0x8ac6cf8>, 'activation2': <function tanh at 0x8c42050>, 'activation1': <function selu at 0x8ac6cf8>, 'wb_initializer1': <tensorflow.python.ops.init_ops.VarianceScaling object at 0xc19f810>, 'out_channels1': 32, 'out_channels2': 46, 'wb_initializer2': <tensorflow.python.ops.init_ops.VarianceScaling object at 0xc19f850>}
# epoch--:9
# Best number of rounds: 6 , best_val_precision: 1.000000 ,best_train_accuracy: 0.987879
# 2018-09-28 11:14:38
# {'fc_nodes1': 853, 'optimizer': 'Adagrad', 'pool_size1': 3, 'pool_size2': 3, 'cstride_size1': 2, 'batch_size': 184, 'cstride_size2': 2, 'pool_type1': <function avg_pool at 0x941b9b0>, 'conv_size1': 6, 'conv_size2': 7, 'pool_type2': <function max_pool at 0x941ba28>, 'pstride_size2': 2, 'pstride_size1': 1, 'fc_initializer2': <tensorflow.python.ops.init_ops.TruncatedNormal object at 0xe6756d0>, 'fc_initializer1': <tensorflow.python.ops.init_ops.VarianceScaling object at 0xc19f850>, 'learning_rate': 0.035844286767361073, 'keep_prob1': 0.36832876944807347, 'fc_activation1': <function sigmoid at 0x8c3eed8>, 'activation2': <function selu at 0x8ac6cf8>, 'activation1': <function elu at 0x8a6cc08>, 'wb_initializer1': <tensorflow.python.ops.init_ops.VarianceScaling object at 0xc19f850>, 'out_channels1': 162, 'out_channels2': 37, 'wb_initializer2': <tensorflow.python.ops.init_ops.VarianceScaling object at 0xc19f810>}
# epoch--:12
# Best number of rounds: 9 , best_val_precision: 0.991189 ,best_train_accuracy: 0.975543
# 2018-09-28 11:19:57
# {'fc_nodes1': 1728, 'optimizer': 'Ftrl', 'pool_size1': 2, 'pool_size2': 3, 'cstride_size1': 2, 'batch_size': 238, 'cstride_size2': 1, 'pool_type1': <function avg_pool at 0x941b9b0>, 'conv_size1': 5, 'conv_size2': 4, 'pool_type2': <function avg_pool at 0x941b9b0>, 'pstride_size2': 2, 'pstride_size1': 2, 'fc_initializer2': <tensorflow.python.ops.init_ops.UniformUnitScaling object at 0xc19f7d0>, 'fc_initializer1': <tensorflow.python.ops.init_ops.RandomNormal object at 0xc19f750>, 'learning_rate': 0.06520019452724296, 'keep_prob1': 0.4992312496417698, 'fc_activation1': <function sigmoid at 0x8c3eed8>, 'activation2': <function relu at 0x8ac6938>, 'activation1': <function softplus at 0x8ad7410>, 'wb_initializer1': <tensorflow.python.ops.init_ops.TruncatedNormal object at 0xe6756d0>, 'out_channels1': 84, 'out_channels2': 184, 'wb_initializer2': <tensorflow.python.ops.init_ops.RandomUniform object at 0xc19f790>}
# epoch--:4
# Best number of rounds: 1 , best_val_precision: 0.872247 ,best_train_accuracy: 0.547899
# 2018-09-28 11:21:31
# {'fc_nodes1': 940, 'optimizer': 'GradientDescend', 'pool_size1': 3, 'pool_size2': 3, 'cstride_size1': 3, 'batch_size': 53, 'cstride_size2': 2, 'pool_type1': <function avg_pool at 0x941b9b0>, 'conv_size1': 5, 'conv_size2': 4, 'pool_type2': <function max_pool at 0x941ba28>, 'pstride_size2': 2, 'pstride_size1': 2, 'fc_initializer2': <tensorflow.python.ops.init_ops.RandomUniform object at 0xc19f790>, 'fc_initializer1': <tensorflow.python.ops.init_ops.VarianceScaling object at 0xc19f850>, 'learning_rate': 0.09834319252675887, 'keep_prob1': 0.06610744183283324, 'fc_activation1': <function tanh at 0x8c42050>, 'activation2': <function elu at 0x8a6cc08>, 'activation1': <function tanh at 0x8c42050>, 'wb_initializer1': <tensorflow.python.ops.init_ops.RandomUniform object at 0xc19f790>, 'out_channels1': 116, 'out_channels2': 192, 'wb_initializer2': <tensorflow.python.ops.init_ops.VarianceScaling object at 0xc19f810>}
# epoch--:8
# Best number of rounds: 5 , best_val_precision: 0.975771 ,best_train_accuracy: 0.950943
# 2018-09-28 11:22:34
# {'fc_nodes1': 1665, 'optimizer': 'Ftrl', 'pool_size1': 3, 'pool_size2': 2, 'cstride_size1': 3, 'batch_size': 212, 'cstride_size2': 1, 'pool_type1': <function avg_pool at 0x941b9b0>, 'conv_size1': 6, 'conv_size2': 5, 'pool_type2': <function avg_pool at 0x941b9b0>, 'pstride_size2': 2, 'pstride_size1': 1, 'fc_initializer2': <tensorflow.python.ops.init_ops.TruncatedNormal object at 0xe6756d0>, 'fc_initializer1': <tensorflow.python.ops.init_ops.TruncatedNormal object at 0xe6756d0>, 'learning_rate': 0.06618158533111233, 'keep_prob1': 0.06511901030225209, 'fc_activation1': <function elu at 0x8a6cc08>, 'activation2': <function tanh at 0x8c42050>, 'activation1': <function softplus at 0x8ad7410>, 'wb_initializer1': <tensorflow.python.ops.init_ops.RandomNormal object at 0xc19f750>, 'out_channels1': 86, 'out_channels2': 98, 'wb_initializer2': <tensorflow.python.ops.init_ops.VarianceScaling object at 0xc19f810>}
# epoch--:5
# Best number of rounds: 2 , best_val_precision: 0.830396 ,best_train_accuracy: 0.683019
# 2018-09-28 11:24:28
# {'fc_nodes1': 145, 'optimizer': 'GradientDescend', 'pool_size1': 3, 'pool_size2': 2, 'cstride_size1': 3, 'batch_size': 95, 'cstride_size2': 1, 'pool_type1': <function max_pool at 0x941ba28>, 'conv_size1': 6, 'conv_size2': 3, 'pool_type2': <function avg_pool at 0x941b9b0>, 'pstride_size2': 2, 'pstride_size1': 2, 'fc_initializer2': <tensorflow.python.ops.init_ops.TruncatedNormal object at 0xe6756d0>, 'fc_initializer1': <tensorflow.python.ops.init_ops.VarianceScaling object at 0xc19f850>, 'learning_rate': 0.016883271336113358, 'keep_prob1': 0.6736697672710368, 'fc_activation1': <function softplus at 0x8ad7410>, 'activation2': <function sigmoid at 0x8c3eed8>, 'activation1': <function elu at 0x8a6cc08>, 'wb_initializer1': <tensorflow.python.ops.init_ops.TruncatedNormal object at 0xe6756d0>, 'out_channels1': 16, 'out_channels2': 47, 'wb_initializer2': <tensorflow.python.ops.init_ops.TruncatedNormal object at 0xe6756d0>}
# epoch--:9
# Best number of rounds: 6 , best_val_precision: 1.000000 ,best_train_accuracy: 0.979825
# 2018-09-28 11:25:09
# {'fc_nodes1': 1299, 'optimizer': 'Adagrad', 'pool_size1': 3, 'pool_size2': 2, 'cstride_size1': 2, 'batch_size': 217, 'cstride_size2': 2, 'pool_type1': <function avg_pool at 0x941b9b0>, 'conv_size1': 7, 'conv_size2': 4, 'pool_type2': <function avg_pool at 0x941b9b0>, 'pstride_size2': 2, 'pstride_size1': 2, 'fc_initializer2': <tensorflow.python.ops.init_ops.RandomNormal object at 0xc19f750>, 'fc_initializer1': <tensorflow.python.ops.init_ops.VarianceScaling object at 0xc19f810>, 'learning_rate': 0.016863809662712444, 'keep_prob1': 0.7912204599626742, 'fc_activation1': <function relu at 0x8ac6938>, 'activation2': <function softplus at 0x8ad7410>, 'activation1': <function tanh at 0x8c42050>, 'wb_initializer1': <tensorflow.python.ops.init_ops.VarianceScaling object at 0xc19f850>, 'out_channels1': 184, 'out_channels2': 46, 'wb_initializer2': <tensorflow.python.ops.init_ops.RandomUniform object at 0xc19f790>}
# epoch--:9
# Best number of rounds: 6 , best_val_precision: 1.000000 ,best_train_accuracy: 0.908756
# 2018-09-28 11:27:02
# {'fc_nodes1': 1223, 'optimizer': 'GradientDescend', 'pool_size1': 3, 'pool_size2': 2, 'cstride_size1': 3, 'batch_size': 46, 'cstride_size2': 1, 'pool_type1': <function max_pool at 0x941ba28>, 'conv_size1': 5, 'conv_size2': 7, 'pool_type2': <function avg_pool at 0x941b9b0>, 'pstride_size2': 2, 'pstride_size1': 1, 'fc_initializer2': <tensorflow.python.ops.init_ops.VarianceScaling object at 0xc19f810>, 'fc_initializer1': <tensorflow.python.ops.init_ops.UniformUnitScaling object at 0xc19f7d0>, 'learning_rate': 0.05973026002963613, 'keep_prob1': 0.43122567265191747, 'fc_activation1': <function sigmoid at 0x8c3eed8>, 'activation2': <function selu at 0x8ac6cf8>, 'activation1': <function tanh at 0x8c42050>, 'wb_initializer1': <tensorflow.python.ops.init_ops.TruncatedNormal object at 0xe6756d0>, 'out_channels1': 113, 'out_channels2': 149, 'wb_initializer2': <tensorflow.python.ops.init_ops.RandomUniform object at 0xc19f790>}
# epoch--:7
# Best number of rounds: 4 , best_val_precision: 1.000000 ,best_train_accuracy: 0.968809
# 2018-09-28 11:32:04
# {'fc_nodes1': 1192, 'optimizer': 'GradientDescend', 'pool_size1': 3, 'pool_size2': 3, 'cstride_size1': 2, 'batch_size': 122, 'cstride_size2': 1, 'pool_type1': <function max_pool at 0x941ba28>, 'conv_size1': 4, 'conv_size2': 4, 'pool_type2': <function avg_pool at 0x941b9b0>, 'pstride_size2': 2, 'pstride_size1': 2, 'fc_initializer2': <tensorflow.python.ops.init_ops.VarianceScaling object at 0xc19f850>, 'fc_initializer1': <tensorflow.python.ops.init_ops.VarianceScaling object at 0xc19f850>, 'learning_rate': 0.08044136326851567, 'keep_prob1': 0.7831210490046985, 'fc_activation1': <function sigmoid at 0x8c3eed8>, 'activation2': <function relu6 at 0x9414de8>, 'activation1': <function softplus at 0x8ad7410>, 'wb_initializer1': <tensorflow.python.ops.init_ops.Constant object at 0xc19f710>, 'out_channels1': 40, 'out_channels2': 69, 'wb_initializer2': <tensorflow.python.ops.init_ops.Constant object at 0xc19f710>}
# epoch--:4
# Best number of rounds: 1 , best_val_precision: 0.872247 ,best_train_accuracy: 0.688525
# 2018-09-28 11:33:00
# {'fc_nodes1': 1496, 'optimizer': 'Momentum', 'pool_size1': 2, 'pool_size2': 2, 'cstride_size1': 3, 'batch_size': 67, 'cstride_size2': 2, 'pool_type1': <function avg_pool at 0x941b9b0>, 'conv_size1': 6, 'conv_size2': 6, 'pool_type2': <function max_pool at 0x941ba28>, 'pstride_size2': 1, 'pstride_size1': 1, 'fc_initializer2': <tensorflow.python.ops.init_ops.UniformUnitScaling object at 0xc19f7d0>, 'fc_initializer1': <tensorflow.python.ops.init_ops.Constant object at 0xc19f710>, 'learning_rate': 0.06795797218725438, 'keep_prob1': 0.04373358651874226, 'fc_activation1': <function elu at 0x8a6cc08>, 'activation2': <function relu6 at 0x9414de8>, 'activation1': <function selu at 0x8ac6cf8>, 'wb_initializer1': <tensorflow.python.ops.init_ops.UniformUnitScaling object at 0xc19f7d0>, 'out_channels1': 98, 'out_channels2': 111, 'wb_initializer2': <tensorflow.python.ops.init_ops.TruncatedNormal object at 0xe6756d0>}
# epoch--:4
# Best number of rounds: 1 , best_val_precision: 0.775330 ,best_train_accuracy: 0.718284
# 2018-09-28 11:34:17
# {'fc_nodes1': 1764, 'optimizer': 'Momentum', 'pool_size1': 2, 'pool_size2': 3, 'cstride_size1': 3, 'batch_size': 230, 'cstride_size2': 1, 'pool_type1': <function max_pool at 0x941ba28>, 'conv_size1': 6, 'conv_size2': 3, 'pool_type2': <function max_pool at 0x941ba28>, 'pstride_size2': 2, 'pstride_size1': 2, 'fc_initializer2': <tensorflow.python.ops.init_ops.TruncatedNormal object at 0xe6756d0>, 'fc_initializer1': <tensorflow.python.ops.init_ops.RandomUniform object at 0xc19f790>, 'learning_rate': 0.0346364232498739, 'keep_prob1': 0.6858927954387267, 'fc_activation1': <function elu at 0x8a6cc08>, 'activation2': <function relu at 0x8ac6938>, 'activation1': <function selu at 0x8ac6cf8>, 'wb_initializer1': <tensorflow.python.ops.init_ops.VarianceScaling object at 0xc19f850>, 'out_channels1': 117, 'out_channels2': 106, 'wb_initializer2': <tensorflow.python.ops.init_ops.VarianceScaling object at 0xc19f810>}
# epoch--:9
# Best number of rounds: 6 , best_val_precision: 1.000000 ,best_train_accuracy: 0.992174
# 2018-09-28 11:35:40
# {'fc_nodes1': 1854, 'optimizer': 'Momentum', 'pool_size1': 2, 'pool_size2': 3, 'cstride_size1': 3, 'batch_size': 163, 'cstride_size2': 1, 'pool_type1': <function avg_pool at 0x941b9b0>, 'conv_size1': 7, 'conv_size2': 7, 'pool_type2': <function avg_pool at 0x941b9b0>, 'pstride_size2': 1, 'pstride_size1': 1, 'fc_initializer2': <tensorflow.python.ops.init_ops.TruncatedNormal object at 0xe6756d0>, 'fc_initializer1': <tensorflow.python.ops.init_ops.VarianceScaling object at 0xc19f850>, 'learning_rate': 0.023558615553697083, 'keep_prob1': 0.8519819809478604, 'fc_activation1': <function relu6 at 0x9414de8>, 'activation2': <function selu at 0x8ac6cf8>, 'activation1': <function tanh at 0x8c42050>, 'wb_initializer1': <tensorflow.python.ops.init_ops.Constant object at 0xc19f710>, 'out_channels1': 79, 'out_channels2': 186, 'wb_initializer2': <tensorflow.python.ops.init_ops.VarianceScaling object at 0xc19f810>}
# epoch--:12
# Best number of rounds: 9 , best_val_precision: 1.000000 ,best_train_accuracy: 0.992112
# 2018-09-28 11:45:00
# {'fc_nodes1': 1487, 'optimizer': 'Momentum', 'pool_size1': 2, 'pool_size2': 2, 'cstride_size1': 2, 'batch_size': 156, 'cstride_size2': 1, 'pool_type1': <function avg_pool at 0x941b9b0>, 'conv_size1': 3, 'conv_size2': 5, 'pool_type2': <function max_pool at 0x941ba28>, 'pstride_size2': 2, 'pstride_size1': 1, 'fc_initializer2': <tensorflow.python.ops.init_ops.TruncatedNormal object at 0xe6756d0>, 'fc_initializer1': <tensorflow.python.ops.init_ops.TruncatedNormal object at 0xe6756d0>, 'learning_rate': 0.0018312291689696343, 'keep_prob1': 0.14953472638429177, 'fc_activation1': <function elu at 0x8a6cc08>, 'activation2': <function relu at 0x8ac6938>, 'activation1': <function elu at 0x8a6cc08>, 'wb_initializer1': <tensorflow.python.ops.init_ops.TruncatedNormal object at 0xe6756d0>, 'out_channels1': 15, 'out_channels2': 24, 'wb_initializer2': <tensorflow.python.ops.init_ops.VarianceScaling object at 0xc19f850>}
# epoch--:4
# Best number of rounds: 1 , best_val_precision: 0.781938 ,best_train_accuracy: 0.570513
# 2018-09-28 11:46:06
# {'fc_nodes1': 226, 'optimizer': 'Momentum', 'pool_size1': 2, 'pool_size2': 2, 'cstride_size1': 2, 'batch_size': 165, 'cstride_size2': 2, 'pool_type1': <function avg_pool at 0x941b9b0>, 'conv_size1': 4, 'conv_size2': 4, 'pool_type2': <function max_pool at 0x941ba28>, 'pstride_size2': 2, 'pstride_size1': 1, 'fc_initializer2': <tensorflow.python.ops.init_ops.VarianceScaling object at 0xc19f810>, 'fc_initializer1': <tensorflow.python.ops.init_ops.VarianceScaling object at 0xc19f810>, 'learning_rate': 0.0582547127846039, 'keep_prob1': 0.21571260891434618, 'fc_activation1': <function sigmoid at 0x8c3eed8>, 'activation2': <function relu at 0x8ac6938>, 'activation1': <function sigmoid at 0x8c3eed8>, 'wb_initializer1': <tensorflow.python.ops.init_ops.RandomNormal object at 0xc19f750>, 'out_channels1': 161, 'out_channels2': 32, 'wb_initializer2': <tensorflow.python.ops.init_ops.UniformUnitScaling object at 0xc19f7d0>}
# epoch--:7
# Best number of rounds: 4 , best_val_precision: 0.892070 ,best_train_accuracy: 0.858874
# 2018-09-28 11:48:03
# {'fc_nodes1': 767, 'optimizer': 'GradientDescend', 'pool_size1': 2, 'pool_size2': 2, 'cstride_size1': 2, 'batch_size': 51, 'cstride_size2': 2, 'pool_type1': <function max_pool at 0x941ba28>, 'conv_size1': 4, 'conv_size2': 6, 'pool_type2': <function max_pool at 0x941ba28>, 'pstride_size2': 2, 'pstride_size1': 1, 'fc_initializer2': <tensorflow.python.ops.init_ops.VarianceScaling object at 0xc19f810>, 'fc_initializer1': <tensorflow.python.ops.init_ops.TruncatedNormal object at 0xe6756d0>, 'learning_rate': 0.05114045851510469, 'keep_prob1': 0.6570733211506564, 'fc_activation1': <function relu6 at 0x9414de8>, 'activation2': <function relu6 at 0x9414de8>, 'activation1': <function sigmoid at 0x8c3eed8>, 'wb_initializer1': <tensorflow.python.ops.init_ops.VarianceScaling object at 0xc19f850>, 'out_channels1': 63, 'out_channels2': 52, 'wb_initializer2': <tensorflow.python.ops.init_ops.UniformUnitScaling object at 0xc19f7d0>}
# epoch--:4
# Best number of rounds: 1 , best_val_precision: 0.872247 ,best_train_accuracy: 0.710551
# 2018-09-28 11:49:13
# {'fc_nodes1': 1909, 'optimizer': 'Adam', 'pool_size1': 3, 'pool_size2': 2, 'cstride_size1': 3, 'batch_size': 53, 'cstride_size2': 1, 'pool_type1': <function avg_pool at 0x941b9b0>, 'conv_size1': 6, 'conv_size2': 4, 'pool_type2': <function avg_pool at 0x941b9b0>, 'pstride_size2': 2, 'pstride_size1': 1, 'fc_initializer2': <tensorflow.python.ops.init_ops.RandomNormal object at 0xc19f750>, 'fc_initializer1': <tensorflow.python.ops.init_ops.UniformUnitScaling object at 0xc19f7d0>, 'learning_rate': 0.07605885970170542, 'keep_prob1': 0.9181452226623914, 'fc_activation1': <function relu6 at 0x9414de8>, 'activation2': <function tanh at 0x8c42050>, 'activation1': <function tanh at 0x8c42050>, 'wb_initializer1': <tensorflow.python.ops.init_ops.Constant object at 0xc19f710>, 'out_channels1': 137, 'out_channels2': 83, 'wb_initializer2': <tensorflow.python.ops.init_ops.Constant object at 0xc19f710>}
# epoch--:6
# Best number of rounds: 3 , best_val_precision: 0.872247 ,best_train_accuracy: 0.728302
# 2018-09-28 11:51:37
# {'fc_nodes1': 1879, 'optimizer': 'Adagrad', 'pool_size1': 2, 'pool_size2': 2, 'cstride_size1': 3, 'batch_size': 35, 'cstride_size2': 2, 'pool_type1': <function avg_pool at 0x941b9b0>, 'conv_size1': 3, 'conv_size2': 6, 'pool_type2': <function avg_pool at 0x941b9b0>, 'pstride_size2': 1, 'pstride_size1': 2, 'fc_initializer2': <tensorflow.python.ops.init_ops.RandomNormal object at 0xc19f750>, 'fc_initializer1': <tensorflow.python.ops.init_ops.RandomUniform object at 0xc19f790>, 'learning_rate': 0.053943864437659146, 'keep_prob1': 0.8140514797421695, 'fc_activation1': <function tanh at 0x8c42050>, 'activation2': <function relu6 at 0x9414de8>, 'activation1': <function tanh at 0x8c42050>, 'wb_initializer1': <tensorflow.python.ops.init_ops.VarianceScaling object at 0xc19f850>, 'out_channels1': 155, 'out_channels2': 116, 'wb_initializer2': <tensorflow.python.ops.init_ops.RandomNormal object at 0xc19f750>}
# epoch--:4
# Best number of rounds: 1 , best_val_precision: 0.986784 ,best_train_accuracy: 0.748387
# 2018-09-28 11:52:37
# {'fc_nodes1': 1073, 'optimizer': 'Adagrad', 'pool_size1': 2, 'pool_size2': 2, 'cstride_size1': 2, 'batch_size': 101, 'cstride_size2': 2, 'pool_type1': <function max_pool at 0x941ba28>, 'conv_size1': 5, 'conv_size2': 4, 'pool_type2': <function avg_pool at 0x941b9b0>, 'pstride_size2': 2, 'pstride_size1': 1, 'fc_initializer2': <tensorflow.python.ops.init_ops.VarianceScaling object at 0xc19f850>, 'fc_initializer1': <tensorflow.python.ops.init_ops.Constant object at 0xc19f710>, 'learning_rate': 0.03961321067829373, 'keep_prob1': 0.7878533102499236, 'fc_activation1': <function selu at 0x8ac6cf8>, 'activation2': <function tanh at 0x8c42050>, 'activation1': <function relu at 0x8ac6938>, 'wb_initializer1': <tensorflow.python.ops.init_ops.VarianceScaling object at 0xc19f810>, 'out_channels1': 114, 'out_channels2': 83, 'wb_initializer2': <tensorflow.python.ops.init_ops.TruncatedNormal object at 0xe6756d0>}
# epoch--:7
# Best number of rounds: 4 , best_val_precision: 1.000000 ,best_train_accuracy: 0.996400
# 2018-09-28 11:54:34
# {'fc_nodes1': 1768, 'optimizer': 'GradientDescend', 'pool_size1': 2, 'pool_size2': 3, 'cstride_size1': 3, 'batch_size': 98, 'cstride_size2': 2, 'pool_type1': <function max_pool at 0x941ba28>, 'conv_size1': 5, 'conv_size2': 4, 'pool_type2': <function max_pool at 0x941ba28>, 'pstride_size2': 1, 'pstride_size1': 1, 'fc_initializer2': <tensorflow.python.ops.init_ops.UniformUnitScaling object at 0xc19f7d0>, 'fc_initializer1': <tensorflow.python.ops.init_ops.Constant object at 0xc19f710>, 'learning_rate': 0.023844394367158198, 'keep_prob1': 0.48563026007652865, 'fc_activation1': <function sigmoid at 0x8c3eed8>, 'activation2': <function elu at 0x8a6cc08>, 'activation1': <function relu6 at 0x9414de8>, 'wb_initializer1': <tensorflow.python.ops.init_ops.VarianceScaling object at 0xc19f850>, 'out_channels1': 98, 'out_channels2': 173, 'wb_initializer2': <tensorflow.python.ops.init_ops.Constant object at 0xc19f710>}
# epoch--:4
# Best number of rounds: 1 , best_val_precision: 0.872247 ,best_train_accuracy: 0.777365
# 2018-09-28 11:55:43
# {'fc_nodes1': 791, 'optimizer': 'RMSProp', 'pool_size1': 2, 'pool_size2': 3, 'cstride_size1': 2, 'batch_size': 114, 'cstride_size2': 1, 'pool_type1': <function max_pool at 0x941ba28>, 'conv_size1': 6, 'conv_size2': 3, 'pool_type2': <function max_pool at 0x941ba28>, 'pstride_size2': 1, 'pstride_size1': 2, 'fc_initializer2': <tensorflow.python.ops.init_ops.RandomUniform object at 0xc19f790>, 'fc_initializer1': <tensorflow.python.ops.init_ops.RandomUniform object at 0xc19f790>, 'learning_rate': 0.09473533061135364, 'keep_prob1': 0.9851525290253668, 'fc_activation1': <function selu at 0x8ac6cf8>, 'activation2': <function sigmoid at 0x8c3eed8>, 'activation1': <function selu at 0x8ac6cf8>, 'wb_initializer1': <tensorflow.python.ops.init_ops.VarianceScaling object at 0xc19f810>, 'out_channels1': 165, 'out_channels2': 57, 'wb_initializer2': <tensorflow.python.ops.init_ops.VarianceScaling object at 0xc19f850>}
# epoch--:7
# Best number of rounds: 4 , best_val_precision: 0.940529 ,best_train_accuracy: 0.727193
# 2018-09-28 11:57:45
# {'fc_nodes1': 1243, 'optimizer': 'Adagrad', 'pool_size1': 3, 'pool_size2': 2, 'cstride_size1': 2, 'batch_size': 251, 'cstride_size2': 2, 'pool_type1': <function max_pool at 0x941ba28>, 'conv_size1': 5, 'conv_size2': 7, 'pool_type2': <function avg_pool at 0x941b9b0>, 'pstride_size2': 1, 'pstride_size1': 2, 'fc_initializer2': <tensorflow.python.ops.init_ops.Constant object at 0xc19f710>, 'fc_initializer1': <tensorflow.python.ops.init_ops.RandomNormal object at 0xc19f750>, 'learning_rate': 0.041381616531600454, 'keep_prob1': 0.9884882744472447, 'fc_activation1': <function selu at 0x8ac6cf8>, 'activation2': <function tanh at 0x8c42050>, 'activation1': <function relu at 0x8ac6938>, 'wb_initializer1': <tensorflow.python.ops.init_ops.VarianceScaling object at 0xc19f810>, 'out_channels1': 36, 'out_channels2': 73, 'wb_initializer2': <tensorflow.python.ops.init_ops.VarianceScaling object at 0xc19f850>}
# epoch--:11
# Best number of rounds: 8 , best_val_precision: 1.000000 ,best_train_accuracy: 0.994422
# 2018-09-28 11:59:13
# {'fc_nodes1': 1468, 'optimizer': 'Adagrad', 'pool_size1': 3, 'pool_size2': 2, 'cstride_size1': 2, 'batch_size': 59, 'cstride_size2': 1, 'pool_type1': <function max_pool at 0x941ba28>, 'conv_size1': 3, 'conv_size2': 7, 'pool_type2': <function avg_pool at 0x941b9b0>, 'pstride_size2': 1, 'pstride_size1': 2, 'fc_initializer2': <tensorflow.python.ops.init_ops.Constant object at 0xc19f710>, 'fc_initializer1': <tensorflow.python.ops.init_ops.RandomNormal object at 0xc19f750>, 'learning_rate': 0.04477007518618813, 'keep_prob1': 0.9944136111892028, 'fc_activation1': <function selu at 0x8ac6cf8>, 'activation2': <function tanh at 0x8c42050>, 'activation1': <function relu at 0x8ac6938>, 'wb_initializer1': <tensorflow.python.ops.init_ops.VarianceScaling object at 0xc19f810>, 'out_channels1': 183, 'out_channels2': 73, 'wb_initializer2': <tensorflow.python.ops.init_ops.VarianceScaling object at 0xc19f850>}
# epoch--:5
# Best number of rounds: 2 , best_val_precision: 1.000000 ,best_train_accuracy: 0.946328
# 2018-09-28 12:02:51
# {'fc_nodes1': 1442, 'optimizer': 'Adam', 'pool_size1': 2, 'pool_size2': 3, 'cstride_size1': 3, 'batch_size': 146, 'cstride_size2': 1, 'pool_type1': <function max_pool at 0x941ba28>, 'conv_size1': 6, 'conv_size2': 3, 'pool_type2': <function max_pool at 0x941ba28>, 'pstride_size2': 1, 'pstride_size1': 2, 'fc_initializer2': <tensorflow.python.ops.init_ops.RandomUniform object at 0xc19f790>, 'fc_initializer1': <tensorflow.python.ops.init_ops.RandomUniform object at 0xc19f790>, 'learning_rate': 0.00016723090073508806, 'keep_prob1': 0.6496957430834921, 'fc_activation1': <function relu at 0x8ac6938>, 'activation2': <function relu at 0x8ac6938>, 'activation1': <function selu at 0x8ac6cf8>, 'wb_initializer1': <tensorflow.python.ops.init_ops.UniformUnitScaling object at 0xc19f7d0>, 'out_channels1': 73, 'out_channels2': 68, 'wb_initializer2': <tensorflow.python.ops.init_ops.RandomNormal object at 0xc19f750>}
# epoch--:7
# Best number of rounds: 4 , best_val_precision: 1.000000 ,best_train_accuracy: 1.000000
# 2018-09-28 12:03:55
# {'fc_nodes1': 1735, 'optimizer': 'RMSProp', 'pool_size1': 2, 'pool_size2': 3, 'cstride_size1': 2, 'batch_size': 251, 'cstride_size2': 2, 'pool_type1': <function max_pool at 0x941ba28>, 'conv_size1': 7, 'conv_size2': 3, 'pool_type2': <function max_pool at 0x941ba28>, 'pstride_size2': 1, 'pstride_size1': 2, 'fc_initializer2': <tensorflow.python.ops.init_ops.Constant object at 0xc19f710>, 'fc_initializer1': <tensorflow.python.ops.init_ops.RandomUniform object at 0xc19f790>, 'learning_rate': 0.03159615000316607, 'keep_prob1': 0.5635249041894499, 'fc_activation1': <function elu at 0x8a6cc08>, 'activation2': <function softplus at 0x8ad7410>, 'activation1': <function relu at 0x8ac6938>, 'wb_initializer1': <tensorflow.python.ops.init_ops.VarianceScaling object at 0xc19f810>, 'out_channels1': 76, 'out_channels2': 106, 'wb_initializer2': <tensorflow.python.ops.init_ops.VarianceScaling object at 0xc19f810>}
# epoch--:6
# Best number of rounds: 3 , best_val_precision: 0.936123 ,best_train_accuracy: 0.709960
# 2018-09-28 12:05:11
# {'fc_nodes1': 626, 'optimizer': 'Adagrad', 'pool_size1': 3, 'pool_size2': 2, 'cstride_size1': 2, 'batch_size': 94, 'cstride_size2': 2, 'pool_type1': <function max_pool at 0x941ba28>, 'conv_size1': 5, 'conv_size2': 7, 'pool_type2': <function avg_pool at 0x941b9b0>, 'pstride_size2': 1, 'pstride_size1': 2, 'fc_initializer2': <tensorflow.python.ops.init_ops.Constant object at 0xc19f710>, 'fc_initializer1': <tensorflow.python.ops.init_ops.RandomNormal object at 0xc19f750>, 'learning_rate': 0.08929253331461325, 'keep_prob1': 0.8887388131320327, 'fc_activation1': <function selu at 0x8ac6cf8>, 'activation2': <function tanh at 0x8c42050>, 'activation1': <function relu6 at 0x9414de8>, 'wb_initializer1': <tensorflow.python.ops.init_ops.VarianceScaling object at 0xc19f810>, 'out_channels1': 186, 'out_channels2': 35, 'wb_initializer2': <tensorflow.python.ops.init_ops.VarianceScaling object at 0xc19f850>}
# epoch--:8
# Best number of rounds: 5 , best_val_precision: 0.980176 ,best_train_accuracy: 0.973404
# 2018-09-28 12:07:16
# {'fc_nodes1': 1452, 'optimizer': 'Adam', 'pool_size1': 3, 'pool_size2': 3, 'cstride_size1': 3, 'batch_size': 208, 'cstride_size2': 1, 'pool_type1': <function max_pool at 0x941ba28>, 'conv_size1': 6, 'conv_size2': 3, 'pool_type2': <function max_pool at 0x941ba28>, 'pstride_size2': 1, 'pstride_size1': 2, 'fc_initializer2': <tensorflow.python.ops.init_ops.RandomUniform object at 0xc19f790>, 'fc_initializer1': <tensorflow.python.ops.init_ops.RandomUniform object at 0xc19f790>, 'learning_rate': 0.07327975724505031, 'keep_prob1': 0.31198600551388556, 'fc_activation1': <function relu at 0x8ac6938>, 'activation2': <function relu at 0x8ac6938>, 'activation1': <function selu at 0x8ac6cf8>, 'wb_initializer1': <tensorflow.python.ops.init_ops.UniformUnitScaling object at 0xc19f7d0>, 'out_channels1': 21, 'out_channels2': 46, 'wb_initializer2': <tensorflow.python.ops.init_ops.RandomNormal object at 0xc19f750>}
# epoch--:10
# Best number of rounds: 7 , best_val_precision: 1.000000 ,best_train_accuracy: 0.994391
# 2018-09-28 12:08:13
# {'fc_nodes1': 511, 'optimizer': 'RMSProp', 'pool_size1': 3, 'pool_size2': 2, 'cstride_size1': 3, 'batch_size': 46, 'cstride_size2': 2, 'pool_type1': <function max_pool at 0x941ba28>, 'conv_size1': 5, 'conv_size2': 7, 'pool_type2': <function avg_pool at 0x941b9b0>, 'pstride_size2': 1, 'pstride_size1': 1, 'fc_initializer2': <tensorflow.python.ops.init_ops.VarianceScaling object at 0xc19f810>, 'fc_initializer1': <tensorflow.python.ops.init_ops.UniformUnitScaling object at 0xc19f7d0>, 'learning_rate': 0.04627764996789837, 'keep_prob1': 0.39476765236613587, 'fc_activation1': <function selu at 0x8ac6cf8>, 'activation2': <function selu at 0x8ac6cf8>, 'activation1': <function relu at 0x8ac6938>, 'wb_initializer1': <tensorflow.python.ops.init_ops.TruncatedNormal object at 0xe6756d0>, 'out_channels1': 170, 'out_channels2': 149, 'wb_initializer2': <tensorflow.python.ops.init_ops.RandomUniform object at 0xc19f790>}
# epoch--:6
# Best number of rounds: 3 , best_val_precision: 1.000000 ,best_train_accuracy: 0.920605
# 2018-09-28 12:10:31
# {'fc_nodes1': 901, 'optimizer': 'RMSProp', 'pool_size1': 3, 'pool_size2': 2, 'cstride_size1': 3, 'batch_size': 142, 'cstride_size2': 2, 'pool_type1': <function max_pool at 0x941ba28>, 'conv_size1': 5, 'conv_size2': 7, 'pool_type2': <function avg_pool at 0x941b9b0>, 'pstride_size2': 1, 'pstride_size1': 1, 'fc_initializer2': <tensorflow.python.ops.init_ops.VarianceScaling object at 0xc19f810>, 'fc_initializer1': <tensorflow.python.ops.init_ops.UniformUnitScaling object at 0xc19f7d0>, 'learning_rate': 0.04405555348920216, 'keep_prob1': 0.30223971937714966, 'fc_activation1': <function selu at 0x8ac6cf8>, 'activation2': <function selu at 0x8ac6cf8>, 'activation1': <function relu at 0x8ac6938>, 'wb_initializer1': <tensorflow.python.ops.init_ops.RandomUniform object at 0xc19f790>, 'out_channels1': 177, 'out_channels2': 31, 'wb_initializer2': <tensorflow.python.ops.init_ops.RandomUniform object at 0xc19f790>}
# epoch--:10
# Best number of rounds: 7 , best_val_precision: 0.997797 ,best_train_accuracy: 0.994718
# 2018-09-28 12:12:53
# {'fc_nodes1': 897, 'optimizer': 'Ftrl', 'pool_size1': 3, 'pool_size2': 2, 'cstride_size1': 2, 'batch_size': 97, 'cstride_size2': 1, 'pool_type1': <function max_pool at 0x941ba28>, 'conv_size1': 3, 'conv_size2': 7, 'pool_type2': <function avg_pool at 0x941b9b0>, 'pstride_size2': 2, 'pstride_size1': 1, 'fc_initializer2': <tensorflow.python.ops.init_ops.VarianceScaling object at 0xc19f810>, 'fc_initializer1': <tensorflow.python.ops.init_ops.UniformUnitScaling object at 0xc19f7d0>, 'learning_rate': 0.0876210080781826, 'keep_prob1': 0.4390269627947418, 'fc_activation1': <function softplus at 0x8ad7410>, 'activation2': <function selu at 0x8ac6cf8>, 'activation1': <function selu at 0x8ac6cf8>, 'wb_initializer1': <tensorflow.python.ops.init_ops.TruncatedNormal object at 0xe6756d0>, 'out_channels1': 166, 'out_channels2': 163, 'wb_initializer2': <tensorflow.python.ops.init_ops.RandomUniform object at 0xc19f790>}
# epoch--:4
# Best number of rounds: 1 , best_val_precision: 0.872247 ,best_train_accuracy: 0.683224
# 2018-09-28 12:20:40
# {'fc_nodes1': 598, 'optimizer': 'RMSProp', 'pool_size1': 3, 'pool_size2': 2, 'cstride_size1': 3, 'batch_size': 153, 'cstride_size2': 2, 'pool_type1': <function max_pool at 0x941ba28>, 'conv_size1': 4, 'conv_size2': 7, 'pool_type2': <function avg_pool at 0x941b9b0>, 'pstride_size2': 1, 'pstride_size1': 1, 'fc_initializer2': <tensorflow.python.ops.init_ops.RandomUniform object at 0xc19f790>, 'fc_initializer1': <tensorflow.python.ops.init_ops.UniformUnitScaling object at 0xc19f7d0>, 'learning_rate': 0.058707438259984104, 'keep_prob1': 0.5722572703377908, 'fc_activation1': <function selu at 0x8ac6cf8>, 'activation2': <function selu at 0x8ac6cf8>, 'activation1': <function sigmoid at 0x8c3eed8>, 'wb_initializer1': <tensorflow.python.ops.init_ops.RandomNormal object at 0xc19f750>, 'out_channels1': 32, 'out_channels2': 185, 'wb_initializer2': <tensorflow.python.ops.init_ops.VarianceScaling object at 0xc19f850>}
# epoch--:13
# Best number of rounds: 10 , best_val_precision: 1.000000 ,best_train_accuracy: 0.990663
# 2018-09-28 12:22:25
# {'fc_nodes1': 16, 'optimizer': 'RMSProp', 'pool_size1': 3, 'pool_size2': 2, 'cstride_size1': 2, 'batch_size': 193, 'cstride_size2': 2, 'pool_type1': <function max_pool at 0x941ba28>, 'conv_size1': 4, 'conv_size2': 5, 'pool_type2': <function avg_pool at 0x941b9b0>, 'pstride_size2': 1, 'pstride_size1': 1, 'fc_initializer2': <tensorflow.python.ops.init_ops.RandomUniform object at 0xc19f790>, 'fc_initializer1': <tensorflow.python.ops.init_ops.RandomNormal object at 0xc19f750>, 'learning_rate': 0.08228226339336157, 'keep_prob1': 0.6099571588698616, 'fc_activation1': <function selu at 0x8ac6cf8>, 'activation2': <function sigmoid at 0x8c3eed8>, 'activation1': <function sigmoid at 0x8c3eed8>, 'wb_initializer1': <tensorflow.python.ops.init_ops.RandomNormal object at 0xc19f750>, 'out_channels1': 100, 'out_channels2': 185, 'wb_initializer2': <tensorflow.python.ops.init_ops.VarianceScaling object at 0xc19f850>}
# epoch--:10
# Best number of rounds: 7 , best_val_precision: 0.887665 ,best_train_accuracy: 0.867876
# 2018-09-28 12:26:06
# {'fc_nodes1': 1602, 'optimizer': 'Adagrad', 'pool_size1': 3, 'pool_size2': 2, 'cstride_size1': 2, 'batch_size': 210, 'cstride_size2': 1, 'pool_type1': <function max_pool at 0x941ba28>, 'conv_size1': 7, 'conv_size2': 7, 'pool_type2': <function avg_pool at 0x941b9b0>, 'pstride_size2': 1, 'pstride_size1': 2, 'fc_initializer2': <tensorflow.python.ops.init_ops.Constant object at 0xc19f710>, 'fc_initializer1': <tensorflow.python.ops.init_ops.RandomNormal object at 0xc19f750>, 'learning_rate': 0.07081181645786516, 'keep_prob1': 0.9562617727884908, 'fc_activation1': <function tanh at 0x8c42050>, 'activation2': <function tanh at 0x8c42050>, 'activation1': <function relu6 at 0x9414de8>, 'wb_initializer1': <tensorflow.python.ops.init_ops.VarianceScaling object at 0xc19f810>, 'out_channels1': 90, 'out_channels2': 13, 'wb_initializer2': <tensorflow.python.ops.init_ops.VarianceScaling object at 0xc19f850>}
# epoch--:9
# Best number of rounds: 6 , best_val_precision: 1.000000 ,best_train_accuracy: 1.000000
# 2018-09-28 12:28:34
# {'fc_nodes1': 2026, 'optimizer': 'Adagrad', 'pool_size1': 2, 'pool_size2': 2, 'cstride_size1': 2, 'batch_size': 101, 'cstride_size2': 1, 'pool_type1': <function max_pool at 0x941ba28>, 'conv_size1': 7, 'conv_size2': 4, 'pool_type2': <function avg_pool at 0x941b9b0>, 'pstride_size2': 2, 'pstride_size1': 2, 'fc_initializer2': <tensorflow.python.ops.init_ops.VarianceScaling object at 0xc19f850>, 'fc_initializer1': <tensorflow.python.ops.init_ops.Constant object at 0xc19f710>, 'learning_rate': 0.008779131914491776, 'keep_prob1': 0.7398453357433513, 'fc_activation1': <function tanh at 0x8c42050>, 'activation2': <function tanh at 0x8c42050>, 'activation1': <function relu6 at 0x9414de8>, 'wb_initializer1': <tensorflow.python.ops.init_ops.VarianceScaling object at 0xc19f810>, 'out_channels1': 101, 'out_channels2': 13, 'wb_initializer2': <tensorflow.python.ops.init_ops.TruncatedNormal object at 0xe6756d0>}
# epoch--:8
# Best number of rounds: 5 , best_val_precision: 1.000000 ,best_train_accuracy: 0.994599
# 2018-09-28 12:30:08
# {'fc_nodes1': 149, 'optimizer': 'Adagrad', 'pool_size1': 2, 'pool_size2': 2, 'cstride_size1': 2, 'batch_size': 185, 'cstride_size2': 2, 'pool_type1': <function max_pool at 0x941ba28>, 'conv_size1': 7, 'conv_size2': 5, 'pool_type2': <function avg_pool at 0x941b9b0>, 'pstride_size2': 2, 'pstride_size1': 2, 'fc_initializer2': <tensorflow.python.ops.init_ops.VarianceScaling object at 0xc19f850>, 'fc_initializer1': <tensorflow.python.ops.init_ops.Constant object at 0xc19f710>, 'learning_rate': 0.0065193412686137125, 'keep_prob1': 0.720826423778606, 'fc_activation1': <function tanh at 0x8c42050>, 'activation2': <function tanh at 0x8c42050>, 'activation1': <function relu6 at 0x9414de8>, 'wb_initializer1': <tensorflow.python.ops.init_ops.VarianceScaling object at 0xc19f810>, 'out_channels1': 43, 'out_channels2': 27, 'wb_initializer2': <tensorflow.python.ops.init_ops.TruncatedNormal object at 0xe6756d0>}
# epoch--:9
# Best number of rounds: 6 , best_val_precision: 0.907489 ,best_train_accuracy: 0.901802
# 2018-09-28 12:31:25
# {'fc_nodes1': 1587, 'optimizer': 'Adam', 'pool_size1': 2, 'pool_size2': 3, 'cstride_size1': 3, 'batch_size': 195, 'cstride_size2': 1, 'pool_type1': <function max_pool at 0x941ba28>, 'conv_size1': 6, 'conv_size2': 3, 'pool_type2': <function max_pool at 0x941ba28>, 'pstride_size2': 1, 'pstride_size1': 2, 'fc_initializer2': <tensorflow.python.ops.init_ops.RandomUniform object at 0xc19f790>, 'fc_initializer1': <tensorflow.python.ops.init_ops.VarianceScaling object at 0xc19f810>, 'learning_rate': 0.09627927746767495, 'keep_prob1': 0.8887711573168777, 'fc_activation1': <function relu at 0x8ac6938>, 'activation2': <function elu at 0x8a6cc08>, 'activation1': <function selu at 0x8ac6cf8>, 'wb_initializer1': <tensorflow.python.ops.init_ops.UniformUnitScaling object at 0xc19f7d0>, 'out_channels1': 187, 'out_channels2': 181, 'wb_initializer2': <tensorflow.python.ops.init_ops.RandomNormal object at 0xc19f750>}
# epoch--:7
# Best number of rounds: 4 , best_val_precision: 0.927313 ,best_train_accuracy: 0.781197
# 2018-09-28 12:33:08
# {'fc_nodes1': 872, 'optimizer': 'GradientDescend', 'pool_size1': 3, 'pool_size2': 2, 'cstride_size1': 3, 'batch_size': 41, 'cstride_size2': 1, 'pool_type1': <function max_pool at 0x941ba28>, 'conv_size1': 5, 'conv_size2': 7, 'pool_type2': <function avg_pool at 0x941b9b0>, 'pstride_size2': 2, 'pstride_size1': 1, 'fc_initializer2': <tensorflow.python.ops.init_ops.VarianceScaling object at 0xc19f810>, 'fc_initializer1': <tensorflow.python.ops.init_ops.UniformUnitScaling object at 0xc19f7d0>, 'learning_rate': 0.06154764994576893, 'keep_prob1': 0.18830938376085427, 'fc_activation1': <function sigmoid at 0x8c3eed8>, 'activation2': <function softplus at 0x8ad7410>, 'activation1': <function tanh at 0x8c42050>, 'wb_initializer1': <tensorflow.python.ops.init_ops.RandomUniform object at 0xc19f790>, 'out_channels1': 10, 'out_channels2': 79, 'wb_initializer2': <tensorflow.python.ops.init_ops.RandomUniform object at 0xc19f790>}
# epoch--:9
# Best number of rounds: 6 , best_val_precision: 1.000000 ,best_train_accuracy: 0.998124
# 2018-09-28 12:34:39
# {'fc_nodes1': 1694, 'optimizer': 'Ftrl', 'pool_size1': 2, 'pool_size2': 2, 'cstride_size1': 2, 'batch_size': 139, 'cstride_size2': 2, 'pool_type1': <function max_pool at 0x941ba28>, 'conv_size1': 5, 'conv_size2': 4, 'pool_type2': <function avg_pool at 0x941b9b0>, 'pstride_size2': 2, 'pstride_size1': 1, 'fc_initializer2': <tensorflow.python.ops.init_ops.VarianceScaling object at 0xc19f850>, 'fc_initializer1': <tensorflow.python.ops.init_ops.Constant object at 0xc19f710>, 'learning_rate': 0.03874901520738104, 'keep_prob1': 0.93229493249739, 'fc_activation1': <function softplus at 0x8ad7410>, 'activation2': <function tanh at 0x8c42050>, 'activation1': <function softplus at 0x8ad7410>, 'wb_initializer1': <tensorflow.python.ops.init_ops.VarianceScaling object at 0xc19f810>, 'out_channels1': 114, 'out_channels2': 128, 'wb_initializer2': <tensorflow.python.ops.init_ops.TruncatedNormal object at 0xe6756d0>}
# epoch--:4
# Best number of rounds: 1 , best_val_precision: 0.872247 ,best_train_accuracy: 0.664568
# 2018-09-28 12:36:06
# {'fc_nodes1': 394, 'optimizer': 'Adam', 'pool_size1': 2, 'pool_size2': 3, 'cstride_size1': 3, 'batch_size': 182, 'cstride_size2': 1, 'pool_type1': <function max_pool at 0x941ba28>, 'conv_size1': 6, 'conv_size2': 3, 'pool_type2': <function max_pool at 0x941ba28>, 'pstride_size2': 2, 'pstride_size1': 2, 'fc_initializer2': <tensorflow.python.ops.init_ops.VarianceScaling object at 0xc19f850>, 'fc_initializer1': <tensorflow.python.ops.init_ops.Constant object at 0xc19f710>, 'learning_rate': 0.028641127169385692, 'keep_prob1': 0.6190671084304431, 'fc_activation1': <function relu at 0x8ac6938>, 'activation2': <function relu at 0x8ac6938>, 'activation1': <function elu at 0x8a6cc08>, 'wb_initializer1': <tensorflow.python.ops.init_ops.UniformUnitScaling object at 0xc19f7d0>, 'out_channels1': 73, 'out_channels2': 198, 'wb_initializer2': <tensorflow.python.ops.init_ops.RandomNormal object at 0xc19f750>}
# epoch--:4
# Best number of rounds: 1 , best_val_precision: 0.872247 ,best_train_accuracy: 0.871795
# 2018-09-28 12:36:53
# {'fc_nodes1': 1426, 'optimizer': 'GradientDescend', 'pool_size1': 3, 'pool_size2': 2, 'cstride_size1': 3, 'batch_size': 177, 'cstride_size2': 2, 'pool_type1': <function max_pool at 0x941ba28>, 'conv_size1': 4, 'conv_size2': 7, 'pool_type2': <function avg_pool at 0x941b9b0>, 'pstride_size2': 2, 'pstride_size1': 1, 'fc_initializer2': <tensorflow.python.ops.init_ops.UniformUnitScaling object at 0xc19f7d0>, 'fc_initializer1': <tensorflow.python.ops.init_ops.UniformUnitScaling object at 0xc19f7d0>, 'learning_rate': 0.05640500086527212, 'keep_prob1': 0.5502558678145718, 'fc_activation1': <function sigmoid at 0x8c3eed8>, 'activation2': <function selu at 0x8ac6cf8>, 'activation1': <function sigmoid at 0x8c3eed8>, 'wb_initializer1': <tensorflow.python.ops.init_ops.RandomNormal object at 0xc19f750>, 'out_channels1': 32, 'out_channels2': 131, 'wb_initializer2': <tensorflow.python.ops.init_ops.RandomUniform object at 0xc19f790>}
# epoch--:8
# Best number of rounds: 5 , best_val_precision: 1.000000 ,best_train_accuracy: 0.903955
# 2018-09-28 12:37:51
# {'fc_nodes1': 1206, 'optimizer': 'Adam', 'pool_size1': 3, 'pool_size2': 3, 'cstride_size1': 3, 'batch_size': 99, 'cstride_size2': 1, 'pool_type1': <function max_pool at 0x941ba28>, 'conv_size1': 4, 'conv_size2': 3, 'pool_type2': <function max_pool at 0x941ba28>, 'pstride_size2': 2, 'pstride_size1': 2, 'fc_initializer2': <tensorflow.python.ops.init_ops.UniformUnitScaling object at 0xc19f7d0>, 'fc_initializer1': <tensorflow.python.ops.init_ops.RandomUniform object at 0xc19f790>, 'learning_rate': 0.052886796138554175, 'keep_prob1': 0.5439649282995513, 'fc_activation1': <function relu at 0x8ac6938>, 'activation2': <function relu at 0x8ac6938>, 'activation1': <function sigmoid at 0x8c3eed8>, 'wb_initializer1': <tensorflow.python.ops.init_ops.RandomNormal object at 0xc19f750>, 'out_channels1': 71, 'out_channels2': 42, 'wb_initializer2': <tensorflow.python.ops.init_ops.RandomNormal object at 0xc19f750>}
# epoch--:9
# Best number of rounds: 6 , best_val_precision: 1.000000 ,best_train_accuracy: 0.999082
# 2018-09-28 12:38:49
# {'fc_nodes1': 32, 'optimizer': 'Adam', 'pool_size1': 3, 'pool_size2': 3, 'cstride_size1': 2, 'batch_size': 117, 'cstride_size2': 2, 'pool_type1': <function avg_pool at 0x941b9b0>, 'conv_size1': 4, 'conv_size2': 6, 'pool_type2': <function max_pool at 0x941ba28>, 'pstride_size2': 1, 'pstride_size1': 2, 'fc_initializer2': <tensorflow.python.ops.init_ops.UniformUnitScaling object at 0xc19f7d0>, 'fc_initializer1': <tensorflow.python.ops.init_ops.RandomNormal object at 0xc19f750>, 'learning_rate': 0.01644617648132808, 'keep_prob1': 0.3521854856395187, 'fc_activation1': <function relu at 0x8ac6938>, 'activation2': <function elu at 0x8a6cc08>, 'activation1': <function sigmoid at 0x8c3eed8>, 'wb_initializer1': <tensorflow.python.ops.init_ops.RandomNormal object at 0xc19f750>, 'out_channels1': 192, 'out_channels2': 142, 'wb_initializer2': <tensorflow.python.ops.init_ops.RandomNormal object at 0xc19f750>}
# epoch--:12
# Best number of rounds: 9 , best_val_precision: 0.931718 ,best_train_accuracy: 0.917949
# 2018-09-28 12:42:31
# {'fc_nodes1': 1073, 'optimizer': 'Adagrad', 'pool_size1': 2, 'pool_size2': 2, 'cstride_size1': 2, 'batch_size': 147, 'cstride_size2': 1, 'pool_type1': <function avg_pool at 0x941b9b0>, 'conv_size1': 5, 'conv_size2': 4, 'pool_type2': <function avg_pool at 0x941b9b0>, 'pstride_size2': 2, 'pstride_size1': 1, 'fc_initializer2': <tensorflow.python.ops.init_ops.VarianceScaling object at 0xc19f850>, 'fc_initializer1': <tensorflow.python.ops.init_ops.Constant object at 0xc19f710>, 'learning_rate': 0.06490567937211063, 'keep_prob1': 0.8112143879757128, 'fc_activation1': <function selu at 0x8ac6cf8>, 'activation2': <function tanh at 0x8c42050>, 'activation1': <function relu at 0x8ac6938>, 'wb_initializer1': <tensorflow.python.ops.init_ops.RandomUniform object at 0xc19f790>, 'out_channels1': 42, 'out_channels2': 65, 'wb_initializer2': <tensorflow.python.ops.init_ops.TruncatedNormal object at 0xe6756d0>}
# epoch--:9
# Best number of rounds: 6 , best_val_precision: 1.000000 ,best_train_accuracy: 0.999150
# 2018-09-28 12:45:07
# {'fc_nodes1': 724, 'optimizer': 'Adagrad', 'pool_size1': 3, 'pool_size2': 2, 'cstride_size1': 2, 'batch_size': 165, 'cstride_size2': 2, 'pool_type1': <function max_pool at 0x941ba28>, 'conv_size1': 6, 'conv_size2': 7, 'pool_type2': <function avg_pool at 0x941b9b0>, 'pstride_size2': 1, 'pstride_size1': 2, 'fc_initializer2': <tensorflow.python.ops.init_ops.Constant object at 0xc19f710>, 'fc_initializer1': <tensorflow.python.ops.init_ops.RandomNormal object at 0xc19f750>, 'learning_rate': 0.07654555455378947, 'keep_prob1': 0.007714749708847557, 'fc_activation1': <function selu at 0x8ac6cf8>, 'activation2': <function sigmoid at 0x8c3eed8>, 'activation1': <function softplus at 0x8ad7410>, 'wb_initializer1': <tensorflow.python.ops.init_ops.Constant object at 0xc19f710>, 'out_channels1': 111, 'out_channels2': 12, 'wb_initializer2': <tensorflow.python.ops.init_ops.VarianceScaling object at 0xc19f850>}
# epoch--:8
# Best number of rounds: 5 , best_val_precision: 0.810573 ,best_train_accuracy: 0.767965
# 2018-09-28 12:46:47
# {'fc_nodes1': 1602, 'optimizer': 'Adagrad', 'pool_size1': 3, 'pool_size2': 2, 'cstride_size1': 2, 'batch_size': 189, 'cstride_size2': 1, 'pool_type1': <function max_pool at 0x941ba28>, 'conv_size1': 7, 'conv_size2': 7, 'pool_type2': <function avg_pool at 0x941b9b0>, 'pstride_size2': 1, 'pstride_size1': 2, 'fc_initializer2': <tensorflow.python.ops.init_ops.Constant object at 0xc19f710>, 'fc_initializer1': <tensorflow.python.ops.init_ops.RandomNormal object at 0xc19f750>, 'learning_rate': 0.06934147431208132, 'keep_prob1': 0.9529241481832138, 'fc_activation1': <function tanh at 0x8c42050>, 'activation2': <function tanh at 0x8c42050>, 'activation1': <function relu6 at 0x9414de8>, 'wb_initializer1': <tensorflow.python.ops.init_ops.VarianceScaling object at 0xc19f810>, 'out_channels1': 90, 'out_channels2': 161, 'wb_initializer2': <tensorflow.python.ops.init_ops.VarianceScaling object at 0xc19f850>}
# epoch--:10
# Best number of rounds: 7 , best_val_precision: 1.000000 ,best_train_accuracy: 0.999118
# 2018-09-28 12:51:33
# {'fc_nodes1': 1383, 'optimizer': 'Ftrl', 'pool_size1': 2, 'pool_size2': 2, 'cstride_size1': 2, 'batch_size': 44, 'cstride_size2': 2, 'pool_type1': <function avg_pool at 0x941b9b0>, 'conv_size1': 3, 'conv_size2': 4, 'pool_type2': <function avg_pool at 0x941b9b0>, 'pstride_size2': 2, 'pstride_size1': 1, 'fc_initializer2': <tensorflow.python.ops.init_ops.RandomNormal object at 0xc19f750>, 'fc_initializer1': <tensorflow.python.ops.init_ops.VarianceScaling object at 0xc19f850>, 'learning_rate': 0.048130827464320715, 'keep_prob1': 0.7348138141997531, 'fc_activation1': <function softplus at 0x8ad7410>, 'activation2': <function softplus at 0x8ad7410>, 'activation1': <function elu at 0x8a6cc08>, 'wb_initializer1': <tensorflow.python.ops.init_ops.VarianceScaling object at 0xc19f810>, 'out_channels1': 121, 'out_channels2': 99, 'wb_initializer2': <tensorflow.python.ops.init_ops.UniformUnitScaling object at 0xc19f7d0>}
# epoch--:4
# Best number of rounds: 1 , best_val_precision: 0.872247 ,best_train_accuracy: 0.749091
# 2018-09-28 12:52:59
# {'fc_nodes1': 561, 'optimizer': 'GradientDescend', 'pool_size1': 3, 'pool_size2': 2, 'cstride_size1': 3, 'batch_size': 28, 'cstride_size2': 1, 'pool_type1': <function max_pool at 0x941ba28>, 'conv_size1': 7, 'conv_size2': 5, 'pool_type2': <function avg_pool at 0x941b9b0>, 'pstride_size2': 2, 'pstride_size1': 1, 'fc_initializer2': <tensorflow.python.ops.init_ops.UniformUnitScaling object at 0xc19f7d0>, 'fc_initializer1': <tensorflow.python.ops.init_ops.TruncatedNormal object at 0xe6756d0>, 'learning_rate': 0.08959469455496306, 'keep_prob1': 0.13637316274983846, 'fc_activation1': <function sigmoid at 0x8c3eed8>, 'activation2': <function selu at 0x8ac6cf8>, 'activation1': <function relu6 at 0x9414de8>, 'wb_initializer1': <tensorflow.python.ops.init_ops.RandomNormal object at 0xc19f750>, 'out_channels1': 38, 'out_channels2': 131, 'wb_initializer2': <tensorflow.python.ops.init_ops.RandomUniform object at 0xc19f790>}
# epoch--:9
# Best number of rounds: 6 , best_val_precision: 0.997797 ,best_train_accuracy: 0.991541
# 2018-09-28 12:55:19
# {'fc_nodes1': 879, 'optimizer': 'RMSProp', 'pool_size1': 2, 'pool_size2': 3, 'cstride_size1': 3, 'batch_size': 254, 'cstride_size2': 1, 'pool_type1': <function max_pool at 0x941ba28>, 'conv_size1': 6, 'conv_size2': 3, 'pool_type2': <function max_pool at 0x941ba28>, 'pstride_size2': 1, 'pstride_size1': 1, 'fc_initializer2': <tensorflow.python.ops.init_ops.VarianceScaling object at 0xc19f810>, 'fc_initializer1': <tensorflow.python.ops.init_ops.VarianceScaling object at 0xc19f810>, 'learning_rate': 0.005099647436935875, 'keep_prob1': 0.24197155880614857, 'fc_activation1': <function relu at 0x8ac6938>, 'activation2': <function relu at 0x8ac6938>, 'activation1': <function selu at 0x8ac6cf8>, 'wb_initializer1': <tensorflow.python.ops.init_ops.TruncatedNormal object at 0xe6756d0>, 'out_channels1': 195, 'out_channels2': 68, 'wb_initializer2': <tensorflow.python.ops.init_ops.Constant object at 0xc19f710>}
# epoch--:6
# Best number of rounds: 3 , best_val_precision: 0.872247 ,best_train_accuracy: 0.777165
# 2018-09-28 12:57:36
# {'fc_nodes1': 1951, 'optimizer': 'Adam', 'pool_size1': 2, 'pool_size2': 3, 'cstride_size1': 3, 'batch_size': 127, 'cstride_size2': 2, 'pool_type1': <function avg_pool at 0x941b9b0>, 'conv_size1': 6, 'conv_size2': 6, 'pool_type2': <function max_pool at 0x941ba28>, 'pstride_size2': 1, 'pstride_size1': 2, 'fc_initializer2': <tensorflow.python.ops.init_ops.RandomUniform object at 0xc19f790>, 'fc_initializer1': <tensorflow.python.ops.init_ops.RandomUniform object at 0xc19f790>, 'learning_rate': 0.011193700581600935, 'keep_prob1': 0.8459147317838942, 'fc_activation1': <function relu6 at 0x9414de8>, 'activation2': <function relu at 0x8ac6938>, 'activation1': <function relu at 0x8ac6938>, 'wb_initializer1': <tensorflow.python.ops.init_ops.UniformUnitScaling object at 0xc19f7d0>, 'out_channels1': 176, 'out_channels2': 132, 'wb_initializer2': <tensorflow.python.ops.init_ops.RandomNormal object at 0xc19f750>}
# epoch--:5
# Best number of rounds: 2 , best_val_precision: 1.000000 ,best_train_accuracy: 0.940507
# 2018-09-28 12:58:40
# {'fc_nodes1': 1214, 'optimizer': 'Adam', 'pool_size1': 2, 'pool_size2': 3, 'cstride_size1': 3, 'batch_size': 140, 'cstride_size2': 1, 'pool_type1': <function avg_pool at 0x941b9b0>, 'conv_size1': 7, 'conv_size2': 6, 'pool_type2': <function max_pool at 0x941ba28>, 'pstride_size2': 1, 'pstride_size1': 2, 'fc_initializer2': <tensorflow.python.ops.init_ops.TruncatedNormal object at 0xe6756d0>, 'fc_initializer1': <tensorflow.python.ops.init_ops.TruncatedNormal object at 0xe6756d0>, 'learning_rate': 0.013601672421054005, 'keep_prob1': 0.8807470073440631, 'fc_activation1': <function relu6 at 0x9414de8>, 'activation2': <function relu6 at 0x9414de8>, 'activation1': <function relu6 at 0x9414de8>, 'wb_initializer1': <tensorflow.python.ops.init_ops.UniformUnitScaling object at 0xc19f7d0>, 'out_channels1': 83, 'out_channels2': 174, 'wb_initializer2': <tensorflow.python.ops.init_ops.UniformUnitScaling object at 0xc19f7d0>}
# epoch--:8
# Best number of rounds: 5 , best_val_precision: 1.000000 ,best_train_accuracy: 0.999107
# best: {'fc_nodes1': 1442, 'pool_size1': 1, 'pool_size2': 0, 'cstride_size1': 0, 'cstride_size2': 0, 'pool_type1': 0, 'pool_type2': 1, 'fc_activation1': 5, 'out_channels1': 22, 'out_channels2': 36, 'optimizer': 2, 'learning_rate': 0.0724362459961808, 'batch_size': 137, 'conv_size1': 3, 'conv_size2': 4, 'pstride_size2': 0, 'pstride_size1': 1, 'fc_initializer2': 3, 'fc_initializer1': 2, 'keep_prob1': 0.9759144277139743, 'activation2': 1, 'activation1': 5, 'wb_initializer1': 5, 'wb_initializer2': 6}
# {'refresh_time': datetime.datetime(2018, 9, 28, 3, 14, 37, 740000), 'book_time': datetime.datetime(2018, 9, 28, 3, 12, 56, 771000), 'misc': {'tid': 1, 'idxs': {'fc_nodes1': [1], 'pool_size1': [1], 'pool_size2': [1], 'cstride_size1': [1], 'cstride_size2': [1], 'pool_type1': [1], 'pool_type2': [1], 'fc_activation1': [1], 'out_channels1': [1], 'out_channels2': [1], 'optimizer': [1], 'learning_rate': [1], 'batch_size': [1], 'conv_size1': [1], 'conv_size2': [1], 'pstride_size2': [1], 'pstride_size1': [1], 'fc_initializer2': [1], 'fc_initializer1': [1], 'keep_prob1': [1], 'activation2': [1], 'activation1': [1], 'wb_initializer1': [1], 'wb_initializer2': [1]}, 'cmd': ('domain_attachment', 'FMinIter_Domain'), 'vals': {'fc_nodes1': [1442], 'pool_size1': [1], 'pool_size2': [0], 'cstride_size1': [0], 'cstride_size2': [0], 'pool_type1': [0], 'pool_type2': [1], 'fc_activation1': [5], 'out_channels1': [22], 'out_channels2': [36], 'optimizer': [2], 'learning_rate': [0.0724362459961808], 'batch_size': [137], 'conv_size1': [3], 'conv_size2': [4], 'pstride_size2': [0], 'pstride_size1': [1], 'fc_initializer2': [3], 'fc_initializer1': [2], 'keep_prob1': [0.9759144277139743], 'activation2': [1], 'activation1': [5], 'wb_initializer1': [5], 'wb_initializer2': [6]}, 'workdir': None}, 'state': 2, 'tid': 1, 'exp_key': None, 'version': 0, 'result': {'status': 'ok', 'loss': -1.0, 'val_accuracy': 1.0, 'train_accuracy': 0.9878787878787879, 'best_rounds': 6}, 'owner': None, 'spec': None}
# 2018-09-28 13:00:41

# %%
start1=datetime.datetime.now()
print(start1)
print (time.strftime("%Y-%m-%d %H:%M:%S",time.localtime()))
train_acc_all_tpe1=[]
test_acc_all_tpe1=[]
best_index_all_tpe1=[]
best_hyperpara_tpe1=[]
max_evals=50
iters=1
doe_num=24
for i in xrange(iters):
    trials = Trials()
    best = fmin(cnn, space, algo=tpe.suggest, trials=trials, verbose=0, max_evals=max_evals,  doe_num=doe_num)    
    print ("iter--:%d"%(i+1))
    print ("best:",best)
    print (trials.best_trial)
    best_hyperpara_tpe1.append(best)
    best_index_tpe=trials.best_trial['misc']['tid']
    best_index_all_tpe1.append(best_index_tpe)    
    ##ACC
    train_acc_tpe=[]
    for i in range(max_evals):
        train_acc_tpe.append(trials.results[i]['train_accuracy'])

    test_acc_tpe=[]
    for i in range(max_evals):
        test_acc_tpe.append(trials.results[i]['val_accuracy'])  
    
    train_acc_all_tpe1.append(train_acc_tpe)
    test_acc_all_tpe1.append(test_acc_tpe)    
        
    rand_result={}
    rand_1={}
    rand_1['train_acc_all_tpe1']=train_acc_all_tpe1
    rand_1['test_acc_all_tpe1']=test_acc_all_tpe1
    rand_1['best_index_all_tpe1']=best_index_all_tpe1
    rand_1['best_hyperpara_tpe1']=best_hyperpara_tpe1

    rand_result['rand_1']=rand_1
    import json
    class MyEncoder(json.JSONEncoder):
        def default(self, obj):
            if isinstance(obj, np.integer):
                return int(obj)
            elif isinstance(obj, np.floating):
                return float(obj)
            elif isinstance(obj, np.ndarray):
                return obj.tolist()
            else:
                return super(MyEncoder, self).default(obj)
    json.dump(rand_result,open('test_cnn1.json','w+'), cls=MyEncoder)
           
print (time.strftime("%Y-%m-%d %H:%M:%S",time.localtime()))
end1=datetime.datetime.now()
print(end1)
timedif1=(end1-start1).seconds
print (timedif1)
# Out:
# 2018-09-10 15:53:16.426968
# 2018-09-10 15:53:16
# 2018-09-10 15:53:17
# {'fc_nodes1': 1110, 'optimizer': 'Momentum', 'pool_size1': 2, 'pool_size2': 3, 'cstride_size1': 3, 'batch_size': 150, 'cstride_size2': 1, 'pool_type1': <function max_pool at 0x8ed5a28>, 'conv_size1': 6, 'conv_size2': 7, 'pool_type2': <function avg_pool at 0x8ed59b0>, 'pstride_size2': 2, 'pstride_size1': 2, 'fc_initializer2': <tensorflow.python.ops.init_ops.UniformUnitScaling object at 0xabc72d0>, 'fc_initializer1': <tensorflow.python.ops.init_ops.Constant object at 0xabc4850>, 'learning_rate': 0.04010824452854456, 'keep_prob1': 0.5910997246715985, 'fc_activation1': <function relu at 0x857f938>, 'activation2': <function sigmoid at 0x86f8ed8>, 'activation1': <function sigmoid at 0x86f8ed8>, 'wb_initializer1': <tensorflow.python.ops.init_ops.RandomUniform object at 0xa1af250>, 'out_channels1': 48, 'out_channels2': 105, 'wb_initializer2': <tensorflow.python.ops.init_ops.Constant object at 0xa0fc410>}
# epoch--:3
# Best number of rounds: 1 , best_val_precision: 0.000000 ,best_train_accuracy: 0.000000
# 2018-09-10 15:53:23
# {'fc_nodes1': 413, 'optimizer': 'Ftrl', 'pool_size1': 3, 'pool_size2': 2, 'cstride_size1': 3, 'batch_size': 48, 'cstride_size2': 1, 'pool_type1': <function max_pool at 0x8ed5a28>, 'conv_size1': 4, 'conv_size2': 3, 'pool_type2': <function avg_pool at 0x8ed59b0>, 'pstride_size2': 1, 'pstride_size1': 1, 'fc_initializer2': <tensorflow.python.ops.init_ops.Constant object at 0xabc71d0>, 'fc_initializer1': <tensorflow.python.ops.init_ops.VarianceScaling object at 0xabc49d0>, 'learning_rate': 0.08428431339644532, 'keep_prob1': 0.6286810812957786, 'fc_activation1': <function sigmoid at 0x86f8ed8>, 'activation2': <function sigmoid at 0x86f8ed8>, 'activation1': <function sigmoid at 0x86f8ed8>, 'wb_initializer1': <tensorflow.python.ops.init_ops.UniformUnitScaling object at 0xa1af290>, 'out_channels1': 55, 'out_channels2': 11, 'wb_initializer2': <tensorflow.python.ops.init_ops.RandomUniform object at 0xa0fc4d0>}
# /usr/lib/python2.7/site-packages/tensorflow/python/client/session.py:1711: UserWarning: An interactive session is already active. This can cause out-of-memory errors in some cases. You must explicitly call `InteractiveSession.close()` to release resources held by the other session(s).
#   warnings.warn('An interactive session is already active. This can '
# epoch--:5
# Best number of rounds: 2 , best_val_precision: 0.872247 ,best_train_accuracy: 0.810764
# 2018-09-10 15:53:33
# {'fc_nodes1': 748, 'optimizer': 'Momentum', 'pool_size1': 3, 'pool_size2': 2, 'cstride_size1': 3, 'batch_size': 201, 'cstride_size2': 2, 'pool_type1': <function avg_pool at 0x8ed59b0>, 'conv_size1': 5, 'conv_size2': 6, 'pool_type2': <function avg_pool at 0x8ed59b0>, 'pstride_size2': 2, 'pstride_size1': 1, 'fc_initializer2': <tensorflow.python.ops.init_ops.VarianceScaling object at 0xabc7350>, 'fc_initializer1': <tensorflow.python.ops.init_ops.Constant object at 0xabc4850>, 'learning_rate': 0.0018465509145886045, 'keep_prob1': 0.6681143800704862, 'fc_activation1': <function elu at 0x8525c08>, 'activation2': <function softplus at 0x8590410>, 'activation1': <function sigmoid at 0x86f8ed8>, 'wb_initializer1': <tensorflow.python.ops.init_ops.RandomNormal object at 0xa1af210>, 'out_channels1': 91, 'out_channels2': 65, 'wb_initializer2': <tensorflow.python.ops.init_ops.VarianceScaling object at 0xa0fc550>}
# epoch--:4
# Best number of rounds: 1 , best_val_precision: 0.872247 ,best_train_accuracy: 0.580431
# 2018-09-10 15:53:41
# {'fc_nodes1': 322, 'optimizer': 'Adam', 'pool_size1': 2, 'pool_size2': 3, 'cstride_size1': 2, 'batch_size': 131, 'cstride_size2': 1, 'pool_type1': <function avg_pool at 0x8ed59b0>, 'conv_size1': 3, 'conv_size2': 6, 'pool_type2': <function avg_pool at 0x8ed59b0>, 'pstride_size2': 2, 'pstride_size1': 2, 'fc_initializer2': <tensorflow.python.ops.init_ops.Constant object at 0xabc71d0>, 'fc_initializer1': <tensorflow.python.ops.init_ops.RandomUniform object at 0xabc4910>, 'learning_rate': 0.02541048384469723, 'keep_prob1': 0.7769902636728901, 'fc_activation1': <function relu6 at 0x8ecede8>, 'activation2': <function relu6 at 0x8ecede8>, 'activation1': <function tanh at 0x86fc050>, 'wb_initializer1': <tensorflow.python.ops.init_ops.TruncatedNormal object at 0xa0e27d0>, 'out_channels1': 147, 'out_channels2': 71, 'wb_initializer2': <tensorflow.python.ops.init_ops.UniformUnitScaling object at 0xa0fc510>}
# epoch--:5
# Best number of rounds: 2 , best_val_precision: 0.872247 ,best_train_accuracy: 0.726718
# 2018-09-10 15:54:16
# {'fc_nodes1': 335, 'optimizer': 'Adam', 'pool_size1': 3, 'pool_size2': 3, 'cstride_size1': 3, 'batch_size': 121, 'cstride_size2': 1, 'pool_type1': <function max_pool at 0x8ed5a28>, 'conv_size1': 6, 'conv_size2': 3, 'pool_type2': <function avg_pool at 0x8ed59b0>, 'pstride_size2': 2, 'pstride_size1': 1, 'fc_initializer2': <tensorflow.python.ops.init_ops.Constant object at 0xabc71d0>, 'fc_initializer1': <tensorflow.python.ops.init_ops.UniformUnitScaling object at 0xabc4950>, 'learning_rate': 0.05567596365130444, 'keep_prob1': 0.46419305224692986, 'fc_activation1': <function sigmoid at 0x86f8ed8>, 'activation2': <function relu6 at 0x8ecede8>, 'activation1': <function elu at 0x8525c08>, 'wb_initializer1': <tensorflow.python.ops.init_ops.RandomNormal object at 0xa1af210>, 'out_channels1': 42, 'out_channels2': 169, 'wb_initializer2': <tensorflow.python.ops.init_ops.VarianceScaling object at 0xa0fc550>}
# epoch--:7
# Best number of rounds: 4 , best_val_precision: 1.000000 ,best_train_accuracy: 0.915702
# 2018-09-10 15:54:36
# {'fc_nodes1': 1926, 'optimizer': 'GradientDescend', 'pool_size1': 2, 'pool_size2': 3, 'cstride_size1': 3, 'batch_size': 81, 'cstride_size2': 2, 'pool_type1': <function max_pool at 0x8ed5a28>, 'conv_size1': 5, 'conv_size2': 6, 'pool_type2': <function avg_pool at 0x8ed59b0>, 'pstride_size2': 2, 'pstride_size1': 2, 'fc_initializer2': <tensorflow.python.ops.init_ops.Constant object at 0xabc71d0>, 'fc_initializer1': <tensorflow.python.ops.init_ops.Constant object at 0xabc4850>, 'learning_rate': 0.0026416413344850106, 'keep_prob1': 0.3145221447091274, 'fc_activation1': <function selu at 0x857fcf8>, 'activation2': <function selu at 0x857fcf8>, 'activation1': <function relu6 at 0x8ecede8>, 'wb_initializer1': <tensorflow.python.ops.init_ops.Constant object at 0xa1af1d0>, 'out_channels1': 43, 'out_channels2': 126, 'wb_initializer2': <tensorflow.python.ops.init_ops.Constant object at 0xa0fc410>}
# epoch--:4
# Best number of rounds: 1 , best_val_precision: 0.872247 ,best_train_accuracy: 0.895944
# 2018-09-10 15:54:41
# {'fc_nodes1': 275, 'optimizer': 'GradientDescend', 'pool_size1': 2, 'pool_size2': 3, 'cstride_size1': 3, 'batch_size': 72, 'cstride_size2': 1, 'pool_type1': <function max_pool at 0x8ed5a28>, 'conv_size1': 6, 'conv_size2': 6, 'pool_type2': <function avg_pool at 0x8ed59b0>, 'pstride_size2': 1, 'pstride_size1': 2, 'fc_initializer2': <tensorflow.python.ops.init_ops.VarianceScaling object at 0xabc7310>, 'fc_initializer1': <tensorflow.python.ops.init_ops.UniformUnitScaling object at 0xabc4950>, 'learning_rate': 0.006776641846943336, 'keep_prob1': 0.7165357099821417, 'fc_activation1': <function sigmoid at 0x86f8ed8>, 'activation2': <function selu at 0x857fcf8>, 'activation1': <function relu at 0x857f938>, 'wb_initializer1': <tensorflow.python.ops.init_ops.UniformUnitScaling object at 0xa1af290>, 'out_channels1': 32, 'out_channels2': 126, 'wb_initializer2': <tensorflow.python.ops.init_ops.RandomNormal object at 0xa0fc490>}
# epoch--:8
# Best number of rounds: 5 , best_val_precision: 0.982379 ,best_train_accuracy: 0.946181
# 2018-09-10 15:54:52
# {'fc_nodes1': 958, 'optimizer': 'Adam', 'pool_size1': 2, 'pool_size2': 2, 'cstride_size1': 2, 'batch_size': 191, 'cstride_size2': 1, 'pool_type1': <function max_pool at 0x8ed5a28>, 'conv_size1': 4, 'conv_size2': 3, 'pool_type2': <function avg_pool at 0x8ed59b0>, 'pstride_size2': 1, 'pstride_size1': 1, 'fc_initializer2': <tensorflow.python.ops.init_ops.TruncatedNormal object at 0xabc7210>, 'fc_initializer1': <tensorflow.python.ops.init_ops.RandomNormal object at 0xabc48d0>, 'learning_rate': 0.014815928527503297, 'keep_prob1': 0.7326828846724348, 'fc_activation1': <function relu6 at 0x8ecede8>, 'activation2': <function tanh at 0x86fc050>, 'activation1': <function relu6 at 0x8ecede8>, 'wb_initializer1': <tensorflow.python.ops.init_ops.UniformUnitScaling object at 0xa1af290>, 'out_channels1': 67, 'out_channels2': 27, 'wb_initializer2': <tensorflow.python.ops.init_ops.TruncatedNormal object at 0xa0fc450>}
# epoch--:5
# Best number of rounds: 2 , best_val_precision: 0.872247 ,best_train_accuracy: 0.656195
# 2018-09-10 15:55:16
# {'fc_nodes1': 410, 'optimizer': 'Momentum', 'pool_size1': 2, 'pool_size2': 3, 'cstride_size1': 3, 'batch_size': 64, 'cstride_size2': 1, 'pool_type1': <function avg_pool at 0x8ed59b0>, 'conv_size1': 5, 'conv_size2': 6, 'pool_type2': <function max_pool at 0x8ed5a28>, 'pstride_size2': 2, 'pstride_size1': 1, 'fc_initializer2': <tensorflow.python.ops.init_ops.RandomNormal object at 0xabc7250>, 'fc_initializer1': <tensorflow.python.ops.init_ops.Constant object at 0xabc4850>, 'learning_rate': 0.034091770198924266, 'keep_prob1': 0.09309295329623146, 'fc_activation1': <function tanh at 0x86fc050>, 'activation2': <function softplus at 0x8590410>, 'activation1': <function tanh at 0x86fc050>, 'wb_initializer1': <tensorflow.python.ops.init_ops.Constant object at 0xa1af1d0>, 'out_channels1': 42, 'out_channels2': 169, 'wb_initializer2': <tensorflow.python.ops.init_ops.UniformUnitScaling object at 0xa0fc510>}
# epoch--:8
# Best number of rounds: 5 , best_val_precision: 0.859031 ,best_train_accuracy: 0.784722
# 2018-09-10 15:55:58
# {'fc_nodes1': 137, 'optimizer': 'Momentum', 'pool_size1': 3, 'pool_size2': 2, 'cstride_size1': 2, 'batch_size': 234, 'cstride_size2': 1, 'pool_type1': <function max_pool at 0x8ed5a28>, 'conv_size1': 5, 'conv_size2': 6, 'pool_type2': <function avg_pool at 0x8ed59b0>, 'pstride_size2': 2, 'pstride_size1': 1, 'fc_initializer2': <tensorflow.python.ops.init_ops.Constant object at 0xabc71d0>, 'fc_initializer1': <tensorflow.python.ops.init_ops.Constant object at 0xabc4850>, 'learning_rate': 0.08459606795735472, 'keep_prob1': 0.14583520467975042, 'fc_activation1': <function relu6 at 0x8ecede8>, 'activation2': <function sigmoid at 0x86f8ed8>, 'activation1': <function tanh at 0x86fc050>, 'wb_initializer1': <tensorflow.python.ops.init_ops.RandomNormal object at 0xa1af210>, 'out_channels1': 107, 'out_channels2': 95, 'wb_initializer2': <tensorflow.python.ops.init_ops.VarianceScaling object at 0xa0fc550>}
# epoch--:4
# Best number of rounds: 1 , best_val_precision: 0.872247 ,best_train_accuracy: 0.908832
# 2018-09-10 15:57:07
# {'fc_nodes1': 1013, 'optimizer': 'RMSProp', 'pool_size1': 3, 'pool_size2': 2, 'cstride_size1': 2, 'batch_size': 167, 'cstride_size2': 2, 'pool_type1': <function avg_pool at 0x8ed59b0>, 'conv_size1': 3, 'conv_size2': 5, 'pool_type2': <function max_pool at 0x8ed5a28>, 'pstride_size2': 1, 'pstride_size1': 1, 'fc_initializer2': <tensorflow.python.ops.init_ops.TruncatedNormal object at 0xabc7210>, 'fc_initializer1': <tensorflow.python.ops.init_ops.Constant object at 0xabc4850>, 'learning_rate': 0.018108092417776216, 'keep_prob1': 0.41846160748749706, 'fc_activation1': <function softplus at 0x8590410>, 'activation2': <function tanh at 0x86fc050>, 'activation1': <function tanh at 0x86fc050>, 'wb_initializer1': <tensorflow.python.ops.init_ops.Constant object at 0xa1af1d0>, 'out_channels1': 47, 'out_channels2': 71, 'wb_initializer2': <tensorflow.python.ops.init_ops.TruncatedNormal object at 0xa0fc450>}
# epoch--:11
# Best number of rounds: 8 , best_val_precision: 1.000000 ,best_train_accuracy: 0.997006
# 2018-09-10 15:57:52
# {'fc_nodes1': 1547, 'optimizer': 'Ftrl', 'pool_size1': 2, 'pool_size2': 3, 'cstride_size1': 2, 'batch_size': 31, 'cstride_size2': 1, 'pool_type1': <function avg_pool at 0x8ed59b0>, 'conv_size1': 7, 'conv_size2': 3, 'pool_type2': <function avg_pool at 0x8ed59b0>, 'pstride_size2': 2, 'pstride_size1': 2, 'fc_initializer2': <tensorflow.python.ops.init_ops.RandomUniform object at 0xabc7290>, 'fc_initializer1': <tensorflow.python.ops.init_ops.RandomNormal object at 0xabc48d0>, 'learning_rate': 0.04610303127794655, 'keep_prob1': 0.7232297033967083, 'fc_activation1': <function softplus at 0x8590410>, 'activation2': <function relu at 0x857f938>, 'activation1': <function relu at 0x857f938>, 'wb_initializer1': <tensorflow.python.ops.init_ops.Constant object at 0xa1af1d0>, 'out_channels1': 136, 'out_channels2': 98, 'wb_initializer2': <tensorflow.python.ops.init_ops.TruncatedNormal object at 0xa0fc450>}
# epoch--:4
# Best number of rounds: 1 , best_val_precision: 0.872247 ,best_train_accuracy: 0.729391
# 2018-09-10 15:58:12
# {'fc_nodes1': 1314, 'optimizer': 'GradientDescend', 'pool_size1': 2, 'pool_size2': 2, 'cstride_size1': 2, 'batch_size': 148, 'cstride_size2': 1, 'pool_type1': <function max_pool at 0x8ed5a28>, 'conv_size1': 3, 'conv_size2': 6, 'pool_type2': <function max_pool at 0x8ed5a28>, 'pstride_size2': 2, 'pstride_size1': 2, 'fc_initializer2': <tensorflow.python.ops.init_ops.VarianceScaling object at 0xabc7310>, 'fc_initializer1': <tensorflow.python.ops.init_ops.RandomUniform object at 0xabc4910>, 'learning_rate': 0.029659406281177303, 'keep_prob1': 0.1616188878077469, 'fc_activation1': <function relu6 at 0x8ecede8>, 'activation2': <function relu at 0x857f938>, 'activation1': <function sigmoid at 0x86f8ed8>, 'wb_initializer1': <tensorflow.python.ops.init_ops.RandomNormal object at 0xa1af210>, 'out_channels1': 55, 'out_channels2': 147, 'wb_initializer2': <tensorflow.python.ops.init_ops.RandomUniform object at 0xa0fc4d0>}
# epoch--:4
# Best number of rounds: 1 , best_val_precision: 0.872247 ,best_train_accuracy: 0.576014
# 2018-09-10 15:58:31
# {'fc_nodes1': 266, 'optimizer': 'RMSProp', 'pool_size1': 2, 'pool_size2': 2, 'cstride_size1': 2, 'batch_size': 99, 'cstride_size2': 1, 'pool_type1': <function avg_pool at 0x8ed59b0>, 'conv_size1': 6, 'conv_size2': 3, 'pool_type2': <function avg_pool at 0x8ed59b0>, 'pstride_size2': 2, 'pstride_size1': 1, 'fc_initializer2': <tensorflow.python.ops.init_ops.UniformUnitScaling object at 0xabc72d0>, 'fc_initializer1': <tensorflow.python.ops.init_ops.RandomUniform object at 0xabc4910>, 'learning_rate': 0.06354686427967732, 'keep_prob1': 0.5395125279559623, 'fc_activation1': <function tanh at 0x86fc050>, 'activation2': <function softplus at 0x8590410>, 'activation1': <function softplus at 0x8590410>, 'wb_initializer1': <tensorflow.python.ops.init_ops.RandomNormal object at 0xa1af210>, 'out_channels1': 59, 'out_channels2': 90, 'wb_initializer2': <tensorflow.python.ops.init_ops.VarianceScaling object at 0xa0fc590>}
# epoch--:7
# Best number of rounds: 4 , best_val_precision: 1.000000 ,best_train_accuracy: 1.000000
# 2018-09-10 15:59:09
# {'fc_nodes1': 283, 'optimizer': 'RMSProp', 'pool_size1': 2, 'pool_size2': 3, 'cstride_size1': 2, 'batch_size': 57, 'cstride_size2': 1, 'pool_type1': <function avg_pool at 0x8ed59b0>, 'conv_size1': 3, 'conv_size2': 7, 'pool_type2': <function max_pool at 0x8ed5a28>, 'pstride_size2': 2, 'pstride_size1': 1, 'fc_initializer2': <tensorflow.python.ops.init_ops.RandomNormal object at 0xabc7250>, 'fc_initializer1': <tensorflow.python.ops.init_ops.Constant object at 0xabc4850>, 'learning_rate': 0.05526457200271143, 'keep_prob1': 0.45556764185308773, 'fc_activation1': <function relu6 at 0x8ecede8>, 'activation2': <function relu6 at 0x8ecede8>, 'activation1': <function softplus at 0x8590410>, 'wb_initializer1': <tensorflow.python.ops.init_ops.TruncatedNormal object at 0xa0e27d0>, 'out_channels1': 133, 'out_channels2': 21, 'wb_initializer2': <tensorflow.python.ops.init_ops.VarianceScaling object at 0xa0fc590>}
# epoch--:4
# Best number of rounds: 1 , best_val_precision: 0.872247 ,best_train_accuracy: 0.524561
# 2018-09-10 16:00:17
# {'fc_nodes1': 256, 'optimizer': 'Adam', 'pool_size1': 3, 'pool_size2': 2, 'cstride_size1': 2, 'batch_size': 177, 'cstride_size2': 2, 'pool_type1': <function max_pool at 0x8ed5a28>, 'conv_size1': 3, 'conv_size2': 6, 'pool_type2': <function avg_pool at 0x8ed59b0>, 'pstride_size2': 2, 'pstride_size1': 1, 'fc_initializer2': <tensorflow.python.ops.init_ops.RandomNormal object at 0xabc7250>, 'fc_initializer1': <tensorflow.python.ops.init_ops.RandomUniform object at 0xabc4910>, 'learning_rate': 0.0452660365171751, 'keep_prob1': 0.2981196296586016, 'fc_activation1': <function sigmoid at 0x86f8ed8>, 'activation2': <function elu at 0x8525c08>, 'activation1': <function relu at 0x857f938>, 'wb_initializer1': <tensorflow.python.ops.init_ops.VarianceScaling object at 0xa0e29d0>, 'out_channels1': 158, 'out_channels2': 37, 'wb_initializer2': <tensorflow.python.ops.init_ops.TruncatedNormal object at 0xa0fc450>}
# epoch--:12
# Best number of rounds: 9 , best_val_precision: 1.000000 ,best_train_accuracy: 0.996234
# 2018-09-10 16:01:28
# {'fc_nodes1': 1175, 'optimizer': 'Adam', 'pool_size1': 2, 'pool_size2': 3, 'cstride_size1': 2, 'batch_size': 150, 'cstride_size2': 2, 'pool_type1': <function max_pool at 0x8ed5a28>, 'conv_size1': 5, 'conv_size2': 5, 'pool_type2': <function max_pool at 0x8ed5a28>, 'pstride_size2': 1, 'pstride_size1': 1, 'fc_initializer2': <tensorflow.python.ops.init_ops.RandomUniform object at 0xabc7290>, 'fc_initializer1': <tensorflow.python.ops.init_ops.RandomUniform object at 0xabc4910>, 'learning_rate': 0.08366989380346367, 'keep_prob1': 0.645237867665741, 'fc_activation1': <function sigmoid at 0x86f8ed8>, 'activation2': <function selu at 0x857fcf8>, 'activation1': <function selu at 0x857fcf8>, 'wb_initializer1': <tensorflow.python.ops.init_ops.UniformUnitScaling object at 0xa1af290>, 'out_channels1': 34, 'out_channels2': 89, 'wb_initializer2': <tensorflow.python.ops.init_ops.Constant object at 0xa0fc410>}
# epoch--:10
# Best number of rounds: 7 , best_val_precision: 1.000000 ,best_train_accuracy: 0.940000
# 2018-09-10 16:02:00
# {'fc_nodes1': 916, 'optimizer': 'Momentum', 'pool_size1': 2, 'pool_size2': 3, 'cstride_size1': 2, 'batch_size': 181, 'cstride_size2': 2, 'pool_type1': <function max_pool at 0x8ed5a28>, 'conv_size1': 7, 'conv_size2': 5, 'pool_type2': <function max_pool at 0x8ed5a28>, 'pstride_size2': 1, 'pstride_size1': 1, 'fc_initializer2': <tensorflow.python.ops.init_ops.UniformUnitScaling object at 0xabc72d0>, 'fc_initializer1': <tensorflow.python.ops.init_ops.RandomNormal object at 0xabc48d0>, 'learning_rate': 0.09801432054330018, 'keep_prob1': 0.7395854623196264, 'fc_activation1': <function elu at 0x8525c08>, 'activation2': <function relu6 at 0x8ecede8>, 'activation1': <function elu at 0x8525c08>, 'wb_initializer1': <tensorflow.python.ops.init_ops.VarianceScaling object at 0xa0e2150>, 'out_channels1': 60, 'out_channels2': 188, 'wb_initializer2': <tensorflow.python.ops.init_ops.RandomNormal object at 0xa0fc490>}
# epoch--:5
# Best number of rounds: 2 , best_val_precision: 0.872247 ,best_train_accuracy: 0.410681
# 2018-09-10 16:02:28
# {'fc_nodes1': 209, 'optimizer': 'RMSProp', 'pool_size1': 2, 'pool_size2': 2, 'cstride_size1': 2, 'batch_size': 116, 'cstride_size2': 1, 'pool_type1': <function avg_pool at 0x8ed59b0>, 'conv_size1': 7, 'conv_size2': 3, 'pool_type2': <function max_pool at 0x8ed5a28>, 'pstride_size2': 2, 'pstride_size1': 2, 'fc_initializer2': <tensorflow.python.ops.init_ops.UniformUnitScaling object at 0xabc72d0>, 'fc_initializer1': <tensorflow.python.ops.init_ops.RandomNormal object at 0xabc48d0>, 'learning_rate': 0.07778774163356364, 'keep_prob1': 0.6544452206608551, 'fc_activation1': <function tanh at 0x86fc050>, 'activation2': <function relu at 0x857f938>, 'activation1': <function tanh at 0x86fc050>, 'wb_initializer1': <tensorflow.python.ops.init_ops.UniformUnitScaling object at 0xa1af290>, 'out_channels1': 116, 'out_channels2': 70, 'wb_initializer2': <tensorflow.python.ops.init_ops.UniformUnitScaling object at 0xa0fc510>}
# epoch--:6
# Best number of rounds: 3 , best_val_precision: 0.872247 ,best_train_accuracy: 0.624138
# 2018-09-10 16:02:48
# {'fc_nodes1': 1312, 'optimizer': 'Momentum', 'pool_size1': 3, 'pool_size2': 2, 'cstride_size1': 2, 'batch_size': 125, 'cstride_size2': 1, 'pool_type1': <function max_pool at 0x8ed5a28>, 'conv_size1': 4, 'conv_size2': 5, 'pool_type2': <function max_pool at 0x8ed5a28>, 'pstride_size2': 2, 'pstride_size1': 1, 'fc_initializer2': <tensorflow.python.ops.init_ops.UniformUnitScaling object at 0xabc72d0>, 'fc_initializer1': <tensorflow.python.ops.init_ops.VarianceScaling object at 0xabc4990>, 'learning_rate': 0.0010283375598611256, 'keep_prob1': 0.1258548974821505, 'fc_activation1': <function elu at 0x8525c08>, 'activation2': <function tanh at 0x86fc050>, 'activation1': <function selu at 0x857fcf8>, 'wb_initializer1': <tensorflow.python.ops.init_ops.Constant object at 0xa1af1d0>, 'out_channels1': 79, 'out_channels2': 117, 'wb_initializer2': <tensorflow.python.ops.init_ops.RandomUniform object at 0xa0fc4d0>}
# epoch--:9
# Best number of rounds: 6 , best_val_precision: 0.991189 ,best_train_accuracy: 0.969600
# 2018-09-10 16:04:33
# {'fc_nodes1': 685, 'optimizer': 'Adagrad', 'pool_size1': 3, 'pool_size2': 3, 'cstride_size1': 2, 'batch_size': 56, 'cstride_size2': 2, 'pool_type1': <function max_pool at 0x8ed5a28>, 'conv_size1': 3, 'conv_size2': 4, 'pool_type2': <function max_pool at 0x8ed5a28>, 'pstride_size2': 1, 'pstride_size1': 1, 'fc_initializer2': <tensorflow.python.ops.init_ops.RandomUniform object at 0xabc7290>, 'fc_initializer1': <tensorflow.python.ops.init_ops.TruncatedNormal object at 0xabc4890>, 'learning_rate': 0.06849857275899576, 'keep_prob1': 0.9701157382400183, 'fc_activation1': <function sigmoid at 0x86f8ed8>, 'activation2': <function elu at 0x8525c08>, 'activation1': <function selu at 0x857fcf8>, 'wb_initializer1': <tensorflow.python.ops.init_ops.VarianceScaling object at 0xa0e29d0>, 'out_channels1': 129, 'out_channels2': 184, 'wb_initializer2': <tensorflow.python.ops.init_ops.Constant object at 0xa0fc410>}
# epoch--:8
# Best number of rounds: 5 , best_val_precision: 1.000000 ,best_train_accuracy: 0.987500
# 2018-09-10 16:05:36
# {'fc_nodes1': 1150, 'optimizer': 'Adagrad', 'pool_size1': 3, 'pool_size2': 2, 'cstride_size1': 2, 'batch_size': 147, 'cstride_size2': 2, 'pool_type1': <function avg_pool at 0x8ed59b0>, 'conv_size1': 5, 'conv_size2': 5, 'pool_type2': <function max_pool at 0x8ed5a28>, 'pstride_size2': 1, 'pstride_size1': 1, 'fc_initializer2': <tensorflow.python.ops.init_ops.TruncatedNormal object at 0xabc7210>, 'fc_initializer1': <tensorflow.python.ops.init_ops.TruncatedNormal object at 0xabc4890>, 'learning_rate': 0.09488035616769207, 'keep_prob1': 0.8763448932657606, 'fc_activation1': <function softplus at 0x8590410>, 'activation2': <function tanh at 0x86fc050>, 'activation1': <function selu at 0x857fcf8>, 'wb_initializer1': <tensorflow.python.ops.init_ops.RandomUniform object at 0xa1af250>, 'out_channels1': 34, 'out_channels2': 159, 'wb_initializer2': <tensorflow.python.ops.init_ops.TruncatedNormal object at 0xa0fc450>}
# epoch--:12
# Best number of rounds: 9 , best_val_precision: 1.000000 ,best_train_accuracy: 0.998299
# 2018-09-10 16:06:27
# {'fc_nodes1': 997, 'optimizer': 'RMSProp', 'pool_size1': 3, 'pool_size2': 2, 'cstride_size1': 2, 'batch_size': 197, 'cstride_size2': 2, 'pool_type1': <function avg_pool at 0x8ed59b0>, 'conv_size1': 5, 'conv_size2': 5, 'pool_type2': <function max_pool at 0x8ed5a28>, 'pstride_size2': 1, 'pstride_size1': 1, 'fc_initializer2': <tensorflow.python.ops.init_ops.RandomUniform object at 0xabc7290>, 'fc_initializer1': <tensorflow.python.ops.init_ops.VarianceScaling object at 0xabc49d0>, 'learning_rate': 0.014146230980362138, 'keep_prob1': 0.3295278366989797, 'fc_activation1': <function softplus at 0x8590410>, 'activation2': <function selu at 0x857fcf8>, 'activation1': <function selu at 0x857fcf8>, 'wb_initializer1': <tensorflow.python.ops.init_ops.VarianceScaling object at 0xa0e2150>, 'out_channels1': 71, 'out_channels2': 109, 'wb_initializer2': <tensorflow.python.ops.init_ops.Constant object at 0xa0fc410>}
# epoch--:8
# Best number of rounds: 5 , best_val_precision: 1.000000 ,best_train_accuracy: 0.893401
# 2018-09-10 16:07:09
# {'fc_nodes1': 128, 'optimizer': 'Adagrad', 'pool_size1': 3, 'pool_size2': 3, 'cstride_size1': 2, 'batch_size': 56, 'cstride_size2': 2, 'pool_type1': <function avg_pool at 0x8ed59b0>, 'conv_size1': 3, 'conv_size2': 4, 'pool_type2': <function max_pool at 0x8ed5a28>, 'pstride_size2': 1, 'pstride_size1': 1, 'fc_initializer2': <tensorflow.python.ops.init_ops.RandomUniform object at 0xabc7290>, 'fc_initializer1': <tensorflow.python.ops.init_ops.VarianceScaling object at 0xabc49d0>, 'learning_rate': 0.06685495737326448, 'keep_prob1': 0.2761532149731427, 'fc_activation1': <function softplus at 0x8590410>, 'activation2': <function elu at 0x8525c08>, 'activation1': <function selu at 0x857fcf8>, 'wb_initializer1': <tensorflow.python.ops.init_ops.VarianceScaling object at 0xa0e2150>, 'out_channels1': 128, 'out_channels2': 109, 'wb_initializer2': <tensorflow.python.ops.init_ops.Constant object at 0xa0fc410>}
# epoch--:8
# Best number of rounds: 5 , best_val_precision: 0.977974 ,best_train_accuracy: 0.942857
# 2018-09-10 16:07:48
# {'fc_nodes1': 691, 'optimizer': 'Adagrad', 'pool_size1': 3, 'pool_size2': 2, 'cstride_size1': 2, 'batch_size': 47, 'cstride_size2': 2, 'pool_type1': <function avg_pool at 0x8ed59b0>, 'conv_size1': 5, 'conv_size2': 4, 'pool_type2': <function max_pool at 0x8ed5a28>, 'pstride_size2': 1, 'pstride_size1': 1, 'fc_initializer2': <tensorflow.python.ops.init_ops.TruncatedNormal object at 0xabc7210>, 'fc_initializer1': <tensorflow.python.ops.init_ops.TruncatedNormal object at 0xabc4890>, 'learning_rate': 0.09849855005441803, 'keep_prob1': 0.9862482525138664, 'fc_activation1': <function relu at 0x857f938>, 'activation2': <function elu at 0x8525c08>, 'activation1': <function selu at 0x857fcf8>, 'wb_initializer1': <tensorflow.python.ops.init_ops.RandomUniform object at 0xa1af250>, 'out_channels1': 150, 'out_channels2': 184, 'wb_initializer2': <tensorflow.python.ops.init_ops.TruncatedNormal object at 0xa0fc450>}
# epoch--:4
# Best number of rounds: 1 , best_val_precision: 1.000000 ,best_train_accuracy: 0.769504
# 2018-09-10 16:08:26
# {'fc_nodes1': 677, 'optimizer': 'Adagrad', 'pool_size1': 3, 'pool_size2': 2, 'cstride_size1': 2, 'batch_size': 47, 'cstride_size2': 2, 'pool_type1': <function avg_pool at 0x8ed59b0>, 'conv_size1': 5, 'conv_size2': 4, 'pool_type2': <function max_pool at 0x8ed5a28>, 'pstride_size2': 1, 'pstride_size1': 1, 'fc_initializer2': <tensorflow.python.ops.init_ops.TruncatedNormal object at 0xabc7210>, 'fc_initializer1': <tensorflow.python.ops.init_ops.TruncatedNormal object at 0xabc4890>, 'learning_rate': 0.016873650073181493, 'keep_prob1': 0.03154849680197358, 'fc_activation1': <function relu at 0x857f938>, 'activation2': <function elu at 0x8525c08>, 'activation1': <function selu at 0x857fcf8>, 'wb_initializer1': <tensorflow.python.ops.init_ops.VarianceScaling object at 0xa0e2150>, 'out_channels1': 110, 'out_channels2': 194, 'wb_initializer2': <tensorflow.python.ops.init_ops.Constant object at 0xa0fc410>}
# epoch--:9
# Best number of rounds: 6 , best_val_precision: 0.797357 ,best_train_accuracy: 0.753546
# 2018-09-10 16:09:34
# {'fc_nodes1': 1232, 'optimizer': 'RMSProp', 'pool_size1': 3, 'pool_size2': 3, 'cstride_size1': 2, 'batch_size': 212, 'cstride_size2': 2, 'pool_type1': <function max_pool at 0x8ed5a28>, 'conv_size1': 3, 'conv_size2': 4, 'pool_type2': <function max_pool at 0x8ed5a28>, 'pstride_size2': 1, 'pstride_size1': 1, 'fc_initializer2': <tensorflow.python.ops.init_ops.RandomUniform object at 0xabc7290>, 'fc_initializer1': <tensorflow.python.ops.init_ops.VarianceScaling object at 0xabc49d0>, 'learning_rate': 0.0695432142179042, 'keep_prob1': 0.3717311730374526, 'fc_activation1': <function selu at 0x857fcf8>, 'activation2': <function selu at 0x857fcf8>, 'activation1': <function selu at 0x857fcf8>, 'wb_initializer1': <tensorflow.python.ops.init_ops.VarianceScaling object at 0xa0e29d0>, 'out_channels1': 129, 'out_channels2': 136, 'wb_initializer2': <tensorflow.python.ops.init_ops.Constant object at 0xa0fc410>}
# epoch--:10
# Best number of rounds: 7 , best_val_precision: 1.000000 ,best_train_accuracy: 0.993711
# 2018-09-10 16:10:40
# {'fc_nodes1': 746, 'optimizer': 'Adagrad', 'pool_size1': 3, 'pool_size2': 2, 'cstride_size1': 2, 'batch_size': 174, 'cstride_size2': 2, 'pool_type1': <function avg_pool at 0x8ed59b0>, 'conv_size1': 5, 'conv_size2': 4, 'pool_type2': <function max_pool at 0x8ed5a28>, 'pstride_size2': 1, 'pstride_size1': 1, 'fc_initializer2': <tensorflow.python.ops.init_ops.VarianceScaling object at 0xabc7350>, 'fc_initializer1': <tensorflow.python.ops.init_ops.VarianceScaling object at 0xabc49d0>, 'learning_rate': 0.03707139081782978, 'keep_prob1': 0.2132309986029927, 'fc_activation1': <function relu at 0x857f938>, 'activation2': <function elu at 0x8525c08>, 'activation1': <function selu at 0x857fcf8>, 'wb_initializer1': <tensorflow.python.ops.init_ops.RandomUniform object at 0xa1af250>, 'out_channels1': 40, 'out_channels2': 145, 'wb_initializer2': <tensorflow.python.ops.init_ops.TruncatedNormal object at 0xa0fc450>}
# epoch--:8
# Best number of rounds: 5 , best_val_precision: 0.969163 ,best_train_accuracy: 0.893678
# 2018-09-10 16:11:10
# {'fc_nodes1': 1625, 'optimizer': 'Adagrad', 'pool_size1': 3, 'pool_size2': 2, 'cstride_size1': 2, 'batch_size': 47, 'cstride_size2': 2, 'pool_type1': <function avg_pool at 0x8ed59b0>, 'conv_size1': 5, 'conv_size2': 7, 'pool_type2': <function max_pool at 0x8ed5a28>, 'pstride_size2': 1, 'pstride_size1': 1, 'fc_initializer2': <tensorflow.python.ops.init_ops.TruncatedNormal object at 0xabc7210>, 'fc_initializer1': <tensorflow.python.ops.init_ops.VarianceScaling object at 0xabc4990>, 'learning_rate': 0.024574435553920165, 'keep_prob1': 0.5434984936640093, 'fc_activation1': <function relu at 0x857f938>, 'activation2': <function selu at 0x857fcf8>, 'activation1': <function selu at 0x857fcf8>, 'wb_initializer1': <tensorflow.python.ops.init_ops.RandomUniform object at 0xa1af250>, 'out_channels1': 171, 'out_channels2': 151, 'wb_initializer2': <tensorflow.python.ops.init_ops.RandomNormal object at 0xa0fc490>}
# epoch--:5
# Best number of rounds: 2 , best_val_precision: 1.000000 ,best_train_accuracy: 0.734043
# 2018-09-10 16:12:22
# {'fc_nodes1': 1780, 'optimizer': 'Adam', 'pool_size1': 3, 'pool_size2': 3, 'cstride_size1': 3, 'batch_size': 175, 'cstride_size2': 1, 'pool_type1': <function max_pool at 0x8ed5a28>, 'conv_size1': 6, 'conv_size2': 4, 'pool_type2': <function avg_pool at 0x8ed59b0>, 'pstride_size2': 2, 'pstride_size1': 1, 'fc_initializer2': <tensorflow.python.ops.init_ops.Constant object at 0xabc71d0>, 'fc_initializer1': <tensorflow.python.ops.init_ops.UniformUnitScaling object at 0xabc4950>, 'learning_rate': 0.05653070372156595, 'keep_prob1': 0.8325353652179077, 'fc_activation1': <function relu at 0x857f938>, 'activation2': <function relu6 at 0x8ecede8>, 'activation1': <function elu at 0x8525c08>, 'wb_initializer1': <tensorflow.python.ops.init_ops.RandomUniform object at 0xa1af250>, 'out_channels1': 113, 'out_channels2': 62, 'wb_initializer2': <tensorflow.python.ops.init_ops.VarianceScaling object at 0xa0fc550>}
# epoch--:4
# Best number of rounds: 1 , best_val_precision: 0.872247 ,best_train_accuracy: 0.735714
# 2018-09-10 16:12:42
# {'fc_nodes1': 1569, 'optimizer': 'Ftrl', 'pool_size1': 3, 'pool_size2': 3, 'cstride_size1': 3, 'batch_size': 93, 'cstride_size2': 1, 'pool_type1': <function max_pool at 0x8ed5a28>, 'conv_size1': 6, 'conv_size2': 3, 'pool_type2': <function avg_pool at 0x8ed59b0>, 'pstride_size2': 2, 'pstride_size1': 2, 'fc_initializer2': <tensorflow.python.ops.init_ops.Constant object at 0xabc71d0>, 'fc_initializer1': <tensorflow.python.ops.init_ops.UniformUnitScaling object at 0xabc4950>, 'learning_rate': 0.09146313236110562, 'keep_prob1': 0.9906539279241635, 'fc_activation1': <function relu at 0x857f938>, 'activation2': <function relu6 at 0x8ecede8>, 'activation1': <function elu at 0x8525c08>, 'wb_initializer1': <tensorflow.python.ops.init_ops.RandomNormal object at 0xa1af210>, 'out_channels1': 141, 'out_channels2': 111, 'wb_initializer2': <tensorflow.python.ops.init_ops.VarianceScaling object at 0xa0fc550>}
# epoch--:4
# Best number of rounds: 1 , best_val_precision: 0.872247 ,best_train_accuracy: 0.901434
# 2018-09-10 16:12:49
# {'fc_nodes1': 1043, 'optimizer': 'Adam', 'pool_size1': 3, 'pool_size2': 3, 'cstride_size1': 3, 'batch_size': 65, 'cstride_size2': 1, 'pool_type1': <function max_pool at 0x8ed5a28>, 'conv_size1': 6, 'conv_size2': 7, 'pool_type2': <function avg_pool at 0x8ed59b0>, 'pstride_size2': 2, 'pstride_size1': 1, 'fc_initializer2': <tensorflow.python.ops.init_ops.RandomNormal object at 0xabc7250>, 'fc_initializer1': <tensorflow.python.ops.init_ops.UniformUnitScaling object at 0xabc4950>, 'learning_rate': 0.04757288036063155, 'keep_prob1': 0.47948316064392915, 'fc_activation1': <function sigmoid at 0x86f8ed8>, 'activation2': <function sigmoid at 0x86f8ed8>, 'activation1': <function relu at 0x857f938>, 'wb_initializer1': <tensorflow.python.ops.init_ops.VarianceScaling object at 0xa0e29d0>, 'out_channels1': 190, 'out_channels2': 167, 'wb_initializer2': <tensorflow.python.ops.init_ops.VarianceScaling object at 0xa0fc550>}
# epoch--:4
# Best number of rounds: 1 , best_val_precision: 0.872247 ,best_train_accuracy: 0.699145
# 2018-09-10 16:13:59
# {'fc_nodes1': 1734, 'optimizer': 'Adam', 'pool_size1': 3, 'pool_size2': 2, 'cstride_size1': 2, 'batch_size': 76, 'cstride_size2': 2, 'pool_type1': <function avg_pool at 0x8ed59b0>, 'conv_size1': 4, 'conv_size2': 4, 'pool_type2': <function avg_pool at 0x8ed59b0>, 'pstride_size2': 1, 'pstride_size1': 1, 'fc_initializer2': <tensorflow.python.ops.init_ops.RandomNormal object at 0xabc7250>, 'fc_initializer1': <tensorflow.python.ops.init_ops.TruncatedNormal object at 0xabc4890>, 'learning_rate': 0.044508822492949573, 'keep_prob1': 0.007292264982125762, 'fc_activation1': <function selu at 0x857fcf8>, 'activation2': <function elu at 0x8525c08>, 'activation1': <function relu at 0x857f938>, 'wb_initializer1': <tensorflow.python.ops.init_ops.VarianceScaling object at 0xa0e29d0>, 'out_channels1': 198, 'out_channels2': 37, 'wb_initializer2': <tensorflow.python.ops.init_ops.TruncatedNormal object at 0xa0fc450>}
# epoch--:12
# Best number of rounds: 9 , best_val_precision: 0.889868 ,best_train_accuracy: 0.819549
# 2018-09-10 16:15:07
# {'fc_nodes1': 1738, 'optimizer': 'RMSProp', 'pool_size1': 2, 'pool_size2': 3, 'cstride_size1': 2, 'batch_size': 197, 'cstride_size2': 2, 'pool_type1': <function avg_pool at 0x8ed59b0>, 'conv_size1': 5, 'conv_size2': 5, 'pool_type2': <function max_pool at 0x8ed5a28>, 'pstride_size2': 1, 'pstride_size1': 1, 'fc_initializer2': <tensorflow.python.ops.init_ops.RandomUniform object at 0xabc7290>, 'fc_initializer1': <tensorflow.python.ops.init_ops.VarianceScaling object at 0xabc49d0>, 'learning_rate': 0.07898794762531808, 'keep_prob1': 0.5943135883568509, 'fc_activation1': <function softplus at 0x8590410>, 'activation2': <function selu at 0x857fcf8>, 'activation1': <function softplus at 0x8590410>, 'wb_initializer1': <tensorflow.python.ops.init_ops.VarianceScaling object at 0xa0e2150>, 'out_channels1': 71, 'out_channels2': 61, 'wb_initializer2': <tensorflow.python.ops.init_ops.Constant object at 0xa0fc410>}
# epoch--:7
# Best number of rounds: 4 , best_val_precision: 1.000000 ,best_train_accuracy: 0.920474
# 2018-09-10 16:15:40
# {'fc_nodes1': 217, 'optimizer': 'Ftrl', 'pool_size1': 2, 'pool_size2': 3, 'cstride_size1': 2, 'batch_size': 61, 'cstride_size2': 2, 'pool_type1': <function max_pool at 0x8ed5a28>, 'conv_size1': 3, 'conv_size2': 5, 'pool_type2': <function max_pool at 0x8ed5a28>, 'pstride_size2': 1, 'pstride_size1': 2, 'fc_initializer2': <tensorflow.python.ops.init_ops.RandomUniform object at 0xabc7290>, 'fc_initializer1': <tensorflow.python.ops.init_ops.RandomUniform object at 0xabc4910>, 'learning_rate': 0.07545765134567904, 'keep_prob1': 0.8978094247815442, 'fc_activation1': <function sigmoid at 0x86f8ed8>, 'activation2': <function sigmoid at 0x86f8ed8>, 'activation1': <function sigmoid at 0x86f8ed8>, 'wb_initializer1': <tensorflow.python.ops.init_ops.UniformUnitScaling object at 0xa1af290>, 'out_channels1': 181, 'out_channels2': 99, 'wb_initializer2': <tensorflow.python.ops.init_ops.Constant object at 0xa0fc410>}
# epoch--:4
# Best number of rounds: 1 , best_val_precision: 0.872247 ,best_train_accuracy: 0.786885
# 2018-09-10 16:15:55
# {'fc_nodes1': 2027, 'optimizer': 'Adagrad', 'pool_size1': 2, 'pool_size2': 3, 'cstride_size1': 3, 'batch_size': 133, 'cstride_size2': 2, 'pool_type1': <function max_pool at 0x8ed5a28>, 'conv_size1': 7, 'conv_size2': 4, 'pool_type2': <function max_pool at 0x8ed5a28>, 'pstride_size2': 1, 'pstride_size1': 1, 'fc_initializer2': <tensorflow.python.ops.init_ops.VarianceScaling object at 0xabc7350>, 'fc_initializer1': <tensorflow.python.ops.init_ops.TruncatedNormal object at 0xabc4890>, 'learning_rate': 0.08713279974744992, 'keep_prob1': 0.9292185257568956, 'fc_activation1': <function sigmoid at 0x86f8ed8>, 'activation2': <function selu at 0x857fcf8>, 'activation1': <function relu6 at 0x8ecede8>, 'wb_initializer1': <tensorflow.python.ops.init_ops.TruncatedNormal object at 0xa0e27d0>, 'out_channels1': 81, 'out_channels2': 35, 'wb_initializer2': <tensorflow.python.ops.init_ops.Constant object at 0xa0fc410>}
# epoch--:10
# Best number of rounds: 7 , best_val_precision: 1.000000 ,best_train_accuracy: 0.945489
# 2018-09-10 16:16:07
# {'fc_nodes1': 485, 'optimizer': 'Adagrad', 'pool_size1': 2, 'pool_size2': 2, 'cstride_size1': 3, 'batch_size': 77, 'cstride_size2': 2, 'pool_type1': <function avg_pool at 0x8ed59b0>, 'conv_size1': 7, 'conv_size2': 4, 'pool_type2': <function max_pool at 0x8ed5a28>, 'pstride_size2': 1, 'pstride_size1': 2, 'fc_initializer2': <tensorflow.python.ops.init_ops.VarianceScaling object at 0xabc7350>, 'fc_initializer1': <tensorflow.python.ops.init_ops.TruncatedNormal object at 0xabc4890>, 'learning_rate': 0.09090589476358278, 'keep_prob1': 0.9471671181764179, 'fc_activation1': <function relu at 0x857f938>, 'activation2': <function softplus at 0x8590410>, 'activation1': <function relu6 at 0x8ecede8>, 'wb_initializer1': <tensorflow.python.ops.init_ops.TruncatedNormal object at 0xa0e27d0>, 'out_channels1': 148, 'out_channels2': 63, 'wb_initializer2': <tensorflow.python.ops.init_ops.VarianceScaling object at 0xa0fc590>}
# epoch--:7
# Best number of rounds: 4 , best_val_precision: 1.000000 ,best_train_accuracy: 0.968460
# 2018-09-10 16:16:17
# {'fc_nodes1': 1704, 'optimizer': 'Adagrad', 'pool_size1': 2, 'pool_size2': 3, 'cstride_size1': 3, 'batch_size': 77, 'cstride_size2': 2, 'pool_type1': <function max_pool at 0x8ed5a28>, 'conv_size1': 7, 'conv_size2': 4, 'pool_type2': <function max_pool at 0x8ed5a28>, 'pstride_size2': 1, 'pstride_size1': 2, 'fc_initializer2': <tensorflow.python.ops.init_ops.VarianceScaling object at 0xabc7350>, 'fc_initializer1': <tensorflow.python.ops.init_ops.TruncatedNormal object at 0xabc4890>, 'learning_rate': 0.07270749580924878, 'keep_prob1': 0.8101713000218675, 'fc_activation1': <function elu at 0x8525c08>, 'activation2': <function softplus at 0x8590410>, 'activation1': <function relu6 at 0x8ecede8>, 'wb_initializer1': <tensorflow.python.ops.init_ops.TruncatedNormal object at 0xa0e27d0>, 'out_channels1': 22, 'out_channels2': 63, 'wb_initializer2': <tensorflow.python.ops.init_ops.VarianceScaling object at 0xa0fc590>}
# epoch--:7
# Best number of rounds: 4 , best_val_precision: 1.000000 ,best_train_accuracy: 0.905380
# 2018-09-10 16:16:25
# {'fc_nodes1': 320, 'optimizer': 'Adagrad', 'pool_size1': 2, 'pool_size2': 2, 'cstride_size1': 3, 'batch_size': 77, 'cstride_size2': 2, 'pool_type1': <function max_pool at 0x8ed5a28>, 'conv_size1': 7, 'conv_size2': 4, 'pool_type2': <function max_pool at 0x8ed5a28>, 'pstride_size2': 1, 'pstride_size1': 2, 'fc_initializer2': <tensorflow.python.ops.init_ops.VarianceScaling object at 0xabc7350>, 'fc_initializer1': <tensorflow.python.ops.init_ops.TruncatedNormal object at 0xabc4890>, 'learning_rate': 0.06059379376071284, 'keep_prob1': 0.8289628820937422, 'fc_activation1': <function elu at 0x8525c08>, 'activation2': <function softplus at 0x8590410>, 'activation1': <function relu6 at 0x8ecede8>, 'wb_initializer1': <tensorflow.python.ops.init_ops.TruncatedNormal object at 0xa0e27d0>, 'out_channels1': 148, 'out_channels2': 63, 'wb_initializer2': <tensorflow.python.ops.init_ops.VarianceScaling object at 0xa0fc590>}
# epoch--:7
# Best number of rounds: 4 , best_val_precision: 1.000000 ,best_train_accuracy: 0.975881
# 2018-09-10 16:16:33
# {'fc_nodes1': 674, 'optimizer': 'GradientDescend', 'pool_size1': 2, 'pool_size2': 2, 'cstride_size1': 3, 'batch_size': 220, 'cstride_size2': 2, 'pool_type1': <function avg_pool at 0x8ed59b0>, 'conv_size1': 7, 'conv_size2': 4, 'pool_type2': <function max_pool at 0x8ed5a28>, 'pstride_size2': 1, 'pstride_size1': 2, 'fc_initializer2': <tensorflow.python.ops.init_ops.VarianceScaling object at 0xabc7350>, 'fc_initializer1': <tensorflow.python.ops.init_ops.TruncatedNormal object at 0xabc4890>, 'learning_rate': 0.06108014139002272, 'keep_prob1': 0.8507700948290388, 'fc_activation1': <function elu at 0x8525c08>, 'activation2': <function softplus at 0x8590410>, 'activation1': <function relu6 at 0x8ecede8>, 'wb_initializer1': <tensorflow.python.ops.init_ops.TruncatedNormal object at 0xa0e27d0>, 'out_channels1': 100, 'out_channels2': 63, 'wb_initializer2': <tensorflow.python.ops.init_ops.VarianceScaling object at 0xa0fc590>}
# epoch--:4
# Best number of rounds: 1 , best_val_precision: 0.872247 ,best_train_accuracy: 0.346970
# 2018-09-10 16:16:39
# {'fc_nodes1': 1476, 'optimizer': 'Adagrad', 'pool_size1': 2, 'pool_size2': 2, 'cstride_size1': 3, 'batch_size': 134, 'cstride_size2': 2, 'pool_type1': <function avg_pool at 0x8ed59b0>, 'conv_size1': 4, 'conv_size2': 4, 'pool_type2': <function max_pool at 0x8ed5a28>, 'pstride_size2': 1, 'pstride_size1': 2, 'fc_initializer2': <tensorflow.python.ops.init_ops.VarianceScaling object at 0xabc7310>, 'fc_initializer1': <tensorflow.python.ops.init_ops.TruncatedNormal object at 0xabc4890>, 'learning_rate': 0.09880667147273306, 'keep_prob1': 0.9496751355218427, 'fc_activation1': <function relu at 0x857f938>, 'activation2': <function softplus at 0x8590410>, 'activation1': <function relu6 at 0x8ecede8>, 'wb_initializer1': <tensorflow.python.ops.init_ops.RandomUniform object at 0xa1af250>, 'out_channels1': 28, 'out_channels2': 129, 'wb_initializer2': <tensorflow.python.ops.init_ops.UniformUnitScaling object at 0xa0fc510>}
# epoch--:4
# Best number of rounds: 1 , best_val_precision: 0.872247 ,best_train_accuracy: 0.460821
# 2018-09-10 16:16:43
# {'fc_nodes1': 1533, 'optimizer': 'Adagrad', 'pool_size1': 3, 'pool_size2': 3, 'cstride_size1': 2, 'batch_size': 52, 'cstride_size2': 2, 'pool_type1': <function max_pool at 0x8ed5a28>, 'conv_size1': 3, 'conv_size2': 7, 'pool_type2': <function max_pool at 0x8ed5a28>, 'pstride_size2': 1, 'pstride_size1': 1, 'fc_initializer2': <tensorflow.python.ops.init_ops.TruncatedNormal object at 0xabc7210>, 'fc_initializer1': <tensorflow.python.ops.init_ops.VarianceScaling object at 0xabc4990>, 'learning_rate': 0.08163372152628082, 'keep_prob1': 0.9812952678096533, 'fc_activation1': <function selu at 0x857fcf8>, 'activation2': <function elu at 0x8525c08>, 'activation1': <function sigmoid at 0x86f8ed8>, 'wb_initializer1': <tensorflow.python.ops.init_ops.VarianceScaling object at 0xa0e29d0>, 'out_channels1': 150, 'out_channels2': 184, 'wb_initializer2': <tensorflow.python.ops.init_ops.RandomUniform object at 0xa0fc4d0>}
# epoch--:5
# Best number of rounds: 2 , best_val_precision: 0.977974 ,best_train_accuracy: 0.748252
# 2018-09-10 16:17:55
# {'fc_nodes1': 1849, 'optimizer': 'GradientDescend', 'pool_size1': 2, 'pool_size2': 3, 'cstride_size1': 3, 'batch_size': 161, 'cstride_size2': 2, 'pool_type1': <function max_pool at 0x8ed5a28>, 'conv_size1': 7, 'conv_size2': 4, 'pool_type2': <function max_pool at 0x8ed5a28>, 'pstride_size2': 1, 'pstride_size1': 2, 'fc_initializer2': <tensorflow.python.ops.init_ops.VarianceScaling object at 0xabc7350>, 'fc_initializer1': <tensorflow.python.ops.init_ops.TruncatedNormal object at 0xabc4890>, 'learning_rate': 0.052004783111641126, 'keep_prob1': 0.8154401282060417, 'fc_activation1': <function elu at 0x8525c08>, 'activation2': <function softplus at 0x8590410>, 'activation1': <function relu6 at 0x8ecede8>, 'wb_initializer1': <tensorflow.python.ops.init_ops.VarianceScaling object at 0xa0e29d0>, 'out_channels1': 129, 'out_channels2': 124, 'wb_initializer2': <tensorflow.python.ops.init_ops.VarianceScaling object at 0xa0fc590>}
# epoch--:4
# Best number of rounds: 1 , best_val_precision: 0.127753 ,best_train_accuracy: 0.462733
# 2018-09-10 16:18:01
# {'fc_nodes1': 937, 'optimizer': 'Ftrl', 'pool_size1': 2, 'pool_size2': 3, 'cstride_size1': 3, 'batch_size': 165, 'cstride_size2': 2, 'pool_type1': <function avg_pool at 0x8ed59b0>, 'conv_size1': 7, 'conv_size2': 5, 'pool_type2': <function max_pool at 0x8ed5a28>, 'pstride_size2': 1, 'pstride_size1': 2, 'fc_initializer2': <tensorflow.python.ops.init_ops.TruncatedNormal object at 0xabc7210>, 'fc_initializer1': <tensorflow.python.ops.init_ops.TruncatedNormal object at 0xabc4890>, 'learning_rate': 0.09305173824918565, 'keep_prob1': 0.7782508886258208, 'fc_activation1': <function softplus at 0x8590410>, 'activation2': <function tanh at 0x86fc050>, 'activation1': <function softplus at 0x8590410>, 'wb_initializer1': <tensorflow.python.ops.init_ops.RandomUniform object at 0xa1af250>, 'out_channels1': 57, 'out_channels2': 104, 'wb_initializer2': <tensorflow.python.ops.init_ops.VarianceScaling object at 0xa0fc590>}
# epoch--:4
# Best number of rounds: 1 , best_val_precision: 0.872247 ,best_train_accuracy: 0.469697
# 2018-09-10 16:18:06
# {'fc_nodes1': 340, 'optimizer': 'Adagrad', 'pool_size1': 3, 'pool_size2': 2, 'cstride_size1': 2, 'batch_size': 222, 'cstride_size2': 2, 'pool_type1': <function avg_pool at 0x8ed59b0>, 'conv_size1': 5, 'conv_size2': 5, 'pool_type2': <function max_pool at 0x8ed5a28>, 'pstride_size2': 1, 'pstride_size1': 1, 'fc_initializer2': <tensorflow.python.ops.init_ops.TruncatedNormal object at 0xabc7210>, 'fc_initializer1': <tensorflow.python.ops.init_ops.VarianceScaling object at 0xabc4990>, 'learning_rate': 0.09356752510799303, 'keep_prob1': 0.8909587094560686, 'fc_activation1': <function softplus at 0x8590410>, 'activation2': <function tanh at 0x86fc050>, 'activation1': <function selu at 0x857fcf8>, 'wb_initializer1': <tensorflow.python.ops.init_ops.RandomUniform object at 0xa1af250>, 'out_channels1': 112, 'out_channels2': 106, 'wb_initializer2': <tensorflow.python.ops.init_ops.TruncatedNormal object at 0xa0fc450>}
# epoch--:9
# Best number of rounds: 6 , best_val_precision: 0.982379 ,best_train_accuracy: 0.948949
# 2018-09-10 16:18:57
# {'fc_nodes1': 1184, 'optimizer': 'RMSProp', 'pool_size1': 2, 'pool_size2': 2, 'cstride_size1': 3, 'batch_size': 113, 'cstride_size2': 2, 'pool_type1': <function max_pool at 0x8ed5a28>, 'conv_size1': 4, 'conv_size2': 6, 'pool_type2': <function max_pool at 0x8ed5a28>, 'pstride_size2': 1, 'pstride_size1': 2, 'fc_initializer2': <tensorflow.python.ops.init_ops.VarianceScaling object at 0xabc7310>, 'fc_initializer1': <tensorflow.python.ops.init_ops.Constant object at 0xabc4850>, 'learning_rate': 0.023333266059965108, 'keep_prob1': 0.3844088166867316, 'fc_activation1': <function elu at 0x8525c08>, 'activation2': <function selu at 0x857fcf8>, 'activation1': <function tanh at 0x86fc050>, 'wb_initializer1': <tensorflow.python.ops.init_ops.VarianceScaling object at 0xa0e2150>, 'out_channels1': 163, 'out_channels2': 191, 'wb_initializer2': <tensorflow.python.ops.init_ops.RandomNormal object at 0xa0fc490>}
# epoch--:7
# Best number of rounds: 4 , best_val_precision: 0.889868 ,best_train_accuracy: 0.761062
# 2018-09-10 16:19:13
# {'fc_nodes1': 1082, 'optimizer': 'RMSProp', 'pool_size1': 2, 'pool_size2': 2, 'cstride_size1': 3, 'batch_size': 37, 'cstride_size2': 2, 'pool_type1': <function max_pool at 0x8ed5a28>, 'conv_size1': 7, 'conv_size2': 5, 'pool_type2': <function max_pool at 0x8ed5a28>, 'pstride_size2': 1, 'pstride_size1': 2, 'fc_initializer2': <tensorflow.python.ops.init_ops.VarianceScaling object at 0xabc7350>, 'fc_initializer1': <tensorflow.python.ops.init_ops.VarianceScaling object at 0xabc49d0>, 'learning_rate': 0.010465001679336762, 'keep_prob1': 0.3538576985444787, 'fc_activation1': <function tanh at 0x86fc050>, 'activation2': <function relu at 0x857f938>, 'activation1': <function relu6 at 0x8ecede8>, 'wb_initializer1': <tensorflow.python.ops.init_ops.VarianceScaling object at 0xa0e2150>, 'out_channels1': 52, 'out_channels2': 120, 'wb_initializer2': <tensorflow.python.ops.init_ops.UniformUnitScaling object at 0xa0fc510>}
# epoch--:8
# Best number of rounds: 5 , best_val_precision: 1.000000 ,best_train_accuracy: 0.935135
# 2018-09-10 16:19:22
# {'fc_nodes1': 1930, 'optimizer': 'Adam', 'pool_size1': 2, 'pool_size2': 3, 'cstride_size1': 3, 'batch_size': 89, 'cstride_size2': 2, 'pool_type1': <function max_pool at 0x8ed5a28>, 'conv_size1': 5, 'conv_size2': 7, 'pool_type2': <function avg_pool at 0x8ed59b0>, 'pstride_size2': 1, 'pstride_size1': 2, 'fc_initializer2': <tensorflow.python.ops.init_ops.RandomUniform object at 0xabc7290>, 'fc_initializer1': <tensorflow.python.ops.init_ops.RandomUniform object at 0xabc4910>, 'learning_rate': 0.062067006906223327, 'keep_prob1': 0.6783373932944217, 'fc_activation1': <function sigmoid at 0x86f8ed8>, 'activation2': <function sigmoid at 0x86f8ed8>, 'activation1': <function sigmoid at 0x86f8ed8>, 'wb_initializer1': <tensorflow.python.ops.init_ops.UniformUnitScaling object at 0xa1af290>, 'out_channels1': 108, 'out_channels2': 89, 'wb_initializer2': <tensorflow.python.ops.init_ops.RandomUniform object at 0xa0fc4d0>}
# epoch--:4
# Best number of rounds: 1 , best_val_precision: 0.872247 ,best_train_accuracy: 0.612360
# 2018-09-10 16:19:27
# {'fc_nodes1': 1524, 'optimizer': 'Momentum', 'pool_size1': 3, 'pool_size2': 3, 'cstride_size1': 3, 'batch_size': 169, 'cstride_size2': 2, 'pool_type1': <function max_pool at 0x8ed5a28>, 'conv_size1': 3, 'conv_size2': 4, 'pool_type2': <function max_pool at 0x8ed5a28>, 'pstride_size2': 1, 'pstride_size1': 2, 'fc_initializer2': <tensorflow.python.ops.init_ops.VarianceScaling object at 0xabc7310>, 'fc_initializer1': <tensorflow.python.ops.init_ops.TruncatedNormal object at 0xabc4890>, 'learning_rate': 0.07184600837675617, 'keep_prob1': 0.7710911427164936, 'fc_activation1': <function relu6 at 0x8ecede8>, 'activation2': <function softplus at 0x8590410>, 'activation1': <function elu at 0x8525c08>, 'wb_initializer1': <tensorflow.python.ops.init_ops.TruncatedNormal object at 0xa0e27d0>, 'out_channels1': 22, 'out_channels2': 143, 'wb_initializer2': <tensorflow.python.ops.init_ops.VarianceScaling object at 0xa0fc590>}
# epoch--:4
# Best number of rounds: 1 , best_val_precision: 0.872247 ,best_train_accuracy: 0.563609
# 2018-09-10 16:19:31
# {'fc_nodes1': 628, 'optimizer': 'RMSProp', 'pool_size1': 3, 'pool_size2': 2, 'cstride_size1': 2, 'batch_size': 129, 'cstride_size2': 2, 'pool_type1': <function avg_pool at 0x8ed59b0>, 'conv_size1': 5, 'conv_size2': 3, 'pool_type2': <function max_pool at 0x8ed5a28>, 'pstride_size2': 1, 'pstride_size1': 1, 'fc_initializer2': <tensorflow.python.ops.init_ops.TruncatedNormal object at 0xabc7210>, 'fc_initializer1': <tensorflow.python.ops.init_ops.VarianceScaling object at 0xabc49d0>, 'learning_rate': 0.0052992693380576, 'keep_prob1': 0.24561742415108223, 'fc_activation1': <function softplus at 0x8590410>, 'activation2': <function selu at 0x857fcf8>, 'activation1': <function selu at 0x857fcf8>, 'wb_initializer1': <tensorflow.python.ops.init_ops.VarianceScaling object at 0xa0e2150>, 'out_channels1': 130, 'out_channels2': 139, 'wb_initializer2': <tensorflow.python.ops.init_ops.TruncatedNormal object at 0xa0fc450>}
# epoch--:11
# Best number of rounds: 8 , best_val_precision: 1.000000 ,best_train_accuracy: 0.989147
# iter--:1
# best: {'fc_nodes1': 325, 'pool_size1': 1, 'pool_size2': 1, 'cstride_size1': 1, 'cstride_size2': 0, 'pool_type1': 0, 'pool_type2': 1, 'fc_activation1': 0, 'out_channels1': 32, 'out_channels2': 159, 'optimizer': 0, 'learning_rate': 0.05567596365130444, 'batch_size': 93, 'conv_size1': 3, 'conv_size2': 0, 'pstride_size2': 1, 'pstride_size1': 0, 'fc_initializer2': 0, 'fc_initializer1': 4, 'keep_prob1': 0.46419305224692986, 'activation2': 6, 'activation1': 4, 'wb_initializer1': 2, 'wb_initializer2': 5}
# 2018-09-10 16:20:28
# 2018-09-10 16:20:28.308491
# 1631

# %%
{'fc_nodes1': 1046, 'optimizer': 'Adam', 'pool_size1': 3, 'pool_size2': 2, 'cstride_size1': 3, 'batch_size': 46, 
 'cstride_size2': 2, 'pool_type1': <function avg_pool at 0x88669b0>, 'conv_size1': 5, 'conv_size2': 3, 
 'pool_type2': <function avg_pool at 0x88669b0>, 'pstride_size2': 2, 'pstride_size1': 1, 
 'fc_initializer2': <tensorflow.python.ops.init_ops.TruncatedNormal object at 0xb6d7990>, 
 'fc_initializer1': <tensorflow.python.ops.init_ops.VarianceScaling object at 0xb6d7150>, 
 'learning_rate': 0.030698641623490844, 'keep_prob1': 0.7899134013022583, 
 'fc_activation1': <function tanh at 0x808d050>, 'activation2': <function tanh at 0x808d050>, 
 'activation1': <function elu at 0x7eb8c08>, 
 'wb_initializer1': <tensorflow.python.ops.init_ops.VarianceScaling object at 0xadfb5d0>, 
 'out_channels1': 197, 'out_channels2': 124, 
 'wb_initializer2': <tensorflow.python.ops.init_ops.Constant object at 0xa654d10>}

best: {'fc_nodes1': 1036, 'pool_size1': 1, 'pool_size2': 0, 'cstride_size1': 1, 'cstride_size2': 1, 
       'pool_type1': 1, 'pool_type2': 1, 'fc_activation1': 1, 'out_channels1': 187, 'out_channels2': 114,
       'optimizer': 0, 'learning_rate': 0.030698641623490844, 'batch_size': 18, 'conv_size1': 2, 'conv_size2': 0,
       'pstride_size2': 1, 'pstride_size1': 0, 'fc_initializer2': 1, 'fc_initializer1': 5,
       'keep_prob1': 0.7899134013022583, 'activation2': 1, 'activation1': 4, 'wb_initializer1': 6, 
       'wb_initializer2': 0}

# %%
#卷积函数
def conv_bn_pool( x, conv_size, channels, out_channels,cstride_size, wb_initializer, activation,pool_type,pool_size,pstride_size, is_training):
    # Create variable named "weights".
    #initializer = tf.random_uniform_initializer(-0.01, 0.01)
    kernel_shape, bias_shape = [conv_size,conv_size,channels,out_channels],[out_channels]
    weights = tf.get_variable(
        name='conv_weights', shape=kernel_shape,initializer=wb_initializer)

    # Create variable named "biases".
    biases = tf.get_variable(
        name='conv_bias', shape=bias_shape,initializer=wb_initializer)
    conv = tf.nn.conv2d(
        x, weights, strides=[1, cstride_size, cstride_size, 1], padding='SAME')
    z = conv + biases
    bn = batch_normalization(z,is_training)
    relu = activation(bn)
    if pool_type != None:
        pool = pool_type(
            relu, ksize=[1, pool_size, pool_size, 1],strides=[1, pstride_size, pstride_size, 1], padding='SAME')

    return pool


def batch_normalization(x,is_training):
    '''
    Realize batch normalization
    '''
    x_shape = x.get_shape()
    params_shape = x_shape[-1]
    axis = list(range(len(x_shape) - 1))
    #The bias for batch normalization
    beta = tf.get_variable(
        name='beta',shape=params_shape,initializer=tf.zeros_initializer)
    #The scale of batch normalization
    gamma = tf.get_variable(
        name='gamma',shape=params_shape,initializer=tf.ones_initializer)
    #Record moving average for testing
    moving_mean = tf.get_variable(
        name='moving_mean',shape=params_shape,initializer=tf.zeros_initializer,trainable=False)
    #Record moving average for testing
    moving_variance = tf.get_variable(
        name='moving_variance',shape=params_shape,initializer=tf.ones_initializer,trainable=False)  
    # These ops will only be preformed when training.
    mean, variance = tf.nn.moments(x, axis)
    #Update moving averages
    decay = 0.95
    update_moving_mean = tf.assign(moving_mean,moving_mean * decay + mean * (1 - decay))
    update_moving_variance = tf.assign(moving_variance,moving_variance * decay + variance * (1 - decay))


    if is_training=='True':
        x = tf.nn.batch_normalization(x, mean, variance, beta, gamma, 0.001)
    else:
        with tf.control_dependencies([update_moving_mean, update_moving_variance]):
            x = tf.nn.batch_normalization(x, moving_mean, moving_variance, beta, gamma, 0.001) 

    return x

initializers = [tf.constant_initializer(0),tf.truncated_normal_initializer(0,0.1),tf.random_normal_initializer(0,0.1),
                                       tf.random_uniform_initializer(-0.1,0.1),tf.uniform_unit_scaling_initializer(),
                                       tf.glorot_uniform_initializer(),tf.glorot_normal_initializer()]
activations = [tf.nn.sigmoid,tf.nn.tanh,tf.nn.relu,tf.nn.softplus,tf.nn.elu,tf.nn.selu,tf.nn.relu6]
optimizers = ['Adam','GradientDescend','Adagrad','Momentum','Ftrl','RMSProp']

bspace = {
    'conv_size1': 5,
    'out_channels1':197,                
    'cstride_size1': 3,
    'wb_initializer1': tf.glorot_normal_initializer(),
    'activation1':tf.nn.elu,
    'pool_type1': tf.nn.avg_pool ,                    
    'pool_size1': 3,                      
    'pstride_size1': 1, 

    'conv_size2': 3,
    'out_channels2': 124,                
    'cstride_size2': 2,
    'wb_initializer2': tf.constant_initializer(0),
    'activation2': tf.nn.tanh,
    'pool_type2': tf.nn.avg_pool,                    
    'pool_size2': 2,                      
    'pstride_size2': 2,  
    
    'fc_nodes1': 1046,   
    'fc_initializer1': tf.glorot_uniform_initializer(),
    'fc_activation1': tf.nn.tanh,
    'keep_prob1':0.7899134013022583 ,
    
    'fc_initializer2': tf.truncated_normal_initializer(0,0.1),
    'optimizer': 'Adam',
    'batch_size' :46,
    'learning_rate':0.030698641623490844 
        }
# Out:
# WARNING:tensorflow:From <ipython-input-5-08f064c00dfd>:60: __init__ (from tensorflow.python.ops.init_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.initializers.variance_scaling instead with distribution=uniform to get equivalent behavior.

# %%
print (time.strftime("%Y-%m-%d %H:%M:%S",time.localtime()))
tf.reset_default_graph()
image_holder = tf.placeholder(tf.float32, [None,90,90,3])
label_holder = tf.placeholder(tf.int32, [None]) 
is_training = tf.placeholder(tf.string) 

with tf.variable_scope('hidden1'):
    h_pool1 = conv_bn_pool(x = image_holder,
                                conv_size = bspace['conv_size1'],
                                channels = 3, 
                                out_channels = bspace['out_channels1'],
                                cstride_size = bspace['cstride_size1'],
                                wb_initializer = bspace['wb_initializer1'],
                                activation = bspace['activation1'],
                                pool_type = bspace['pool_type1'],
                                pool_size = bspace['pool_size1'],
                                pstride_size = bspace['pstride_size1'],
                                is_training = is_training)
    
with tf.variable_scope('hidden2'):
    h_pool2 = conv_bn_pool(x = h_pool1,
                                conv_size = bspace['conv_size2'],
                                channels = bspace['out_channels1'], 
                                out_channels = bspace['out_channels2'],
                                cstride_size = bspace['cstride_size2'],
                                wb_initializer = bspace['wb_initializer2'],
                                activation = bspace['activation2'],
                                pool_type = bspace['pool_type2'],
                                pool_size = bspace['pool_size2'],
                                pstride_size = bspace['pstride_size2'],
                                is_training = is_training)

with tf.variable_scope('fully_conn1'):
    h_pool2_flat = tf.reshape(h_pool2, [-1, np.prod(h_pool2.shape[1:])])
    W_fc1 = tf.get_variable(
        name='weights1', shape=[np.prod(h_pool2.shape[1:]), bspace['fc_nodes1']],
        initializer=bspace['fc_initializer1'])
    b_fc1 = tf.get_variable(name='bias1', shape=[bspace['fc_nodes1']],initializer=bspace['fc_initializer1'])
    h_fc1 = bspace['fc_activation1'](
        batch_normalization(tf.matmul(h_pool2_flat, W_fc1) + b_fc1,is_training)) 
    h_fc1_drop = tf.nn.dropout(h_fc1, bspace['keep_prob1'])

#Softmax Layer
with tf.variable_scope('softmax_layers'):
    W_fc2 = tf.get_variable(name='weights2', shape=[bspace['fc_nodes1'], 2],initializer=bspace['fc_initializer2'])
    b_fc2 = tf.get_variable(name='bias2', shape=[2],initializer=bspace['fc_initializer2'])
    logits = tf.matmul(h_fc1_drop, W_fc2) + b_fc2

cross_entropy = tf.losses.sparse_softmax_cross_entropy(labels=label_holder, logits=logits)
loss = tf.reduce_mean(cross_entropy)

global_step=tf.Variable(0)
lr=tf.train.exponential_decay(bspace['learning_rate'],global_step,10,0.95,staircase=True)
if bspace['optimizer']=='Adam':
    train_op = tf.train.AdamOptimizer(lr).minimize(loss)
elif bspace['optimizer']=='GradientDescend':
    train_op = tf.train.GradientDescentOptimizer(lr).minimize(loss)
elif bspace['optimizer']=='Adagrad':
    train_op = tf.train.AdagradOptimizer(0.01).minimize(loss)            
elif bspace['optimizer']=='Momentum':
    train_op = tf.train.MomentumOptimizer(lr,0.25).minimize(loss)
elif bspace['optimizer']=='Ftrl':
    train_op = tf.train.FtrlOptimizer(lr).minimize(loss)            
else :
    train_op = tf.train.RMSPropOptimizer(lr).minimize(loss)  

top_k_op = tf.nn.in_top_k(logits, label_holder, 1)

#print(bspace)
epochs = 15
train_num_examples=y_train.shape[0]
max_steps = int(math.ceil(train_num_examples / (bspace['batch_size']+0.0)))
total_sample_train = max_steps * bspace['batch_size']

best = 0
wait = 0  #counter for patience
best_rounds =1
counter=0
patience=2
ckpt_dir='./model_save/s'
train_acc_all=[]

min_fraction_of_examples_in_queue = 0.4
min_queue_examples = int(y_train.shape[0] * min_fraction_of_examples_in_queue)
input_queue=tf.train.slice_input_producer([X_train,y_train],shuffle=False)
X_batch,y_batch = tf.train.batch(input_queue,batch_size=bspace['batch_size'],num_threads=100,
                                 capacity=min_queue_examples + 3 * bspace['batch_size'])  
# 定义会话并开始迭代训练
sess = tf.InteractiveSession()
tf.global_variables_initializer().run()
# 启动图片数据增强的线程队列
coord = tf.train.Coordinator()
threads = tf.train.start_queue_runners(coord=coord)
for epoch in xrange(epochs):
    #print ("epoch--:%d"%(epoch+1))
    true_count_train = 0
    for step in xrange(max_steps):
        image_batch, label_batch = sess.run([X_batch,y_batch])
        feed_dict ={image_holder: image_batch,label_holder: label_batch, is_training: 'True'}
        #Train
        _, l, a = sess.run([train_op, loss,top_k_op],feed_dict=feed_dict)
        true_count_train += np.sum(a)
    train_accuracy = true_count_train / total_sample_train
    train_acc_all.append(train_accuracy)
    
    true_count = 0
    accuracy = sess.run([top_k_op],feed_dict={image_holder: X_val,label_holder: y_val, is_training: 'False'})
    true_count += np.sum(accuracy)
    current_accuracy = true_count / y_val.shape[0]
    counter +=1

    if current_accuracy > best:
        best = current_accuracy
        best_rounds=counter
        wait = 0
        if not os.path.exists(ckpt_dir):
            os.makedirs(ckpt_dir)
        saver=tf.train.Saver()
        saver.save(sess,ckpt_dir+"/cnn1.ckpt")
    else:
        wait += 1 #incremental the number of times without improvement
        if wait >= patience : #no more patience, retrieve best model
            break
    print ("epoch--:%d"%(epoch+1))
    print('Best number of rounds: %d , best_val_precision: %f ,best_train_accuracy: %f' % 
          (best_rounds, best,train_acc_all[best_rounds-1]))
    
print (time.strftime("%Y-%m-%d %H:%M:%S",time.localtime()))    
try: 
    saver
except NameError:
    print ('saver_exists=False')
else:
    saver.restore(sess,ckpt_dir+"/cnn1.ckpt")   
print('####################################')
print (time.strftime("%Y-%m-%d %H:%M:%S",time.localtime()))
te_1_logits=logits.eval(feed_dict={image_holder: te_imgs_1,label_holder: te_labels_1,is_training: 'False'})
te_h1_logits=logits.eval(feed_dict={image_holder: te_imgs_h1,label_holder: te_labels_h1,is_training: 'False'})
te_v1_logits=logits.eval(feed_dict={image_holder: te_imgs_v1,label_holder: te_labels_v1,is_training: 'False'})
te_hv1_logits=logits.eval(feed_dict={image_holder: te_imgs_hv1,label_holder: te_labels_hv1,is_training: 'False'})
te_2_logits=logits.eval(feed_dict={image_holder: te_imgs_2,label_holder: te_labels_2,is_training: 'False'})
te_h2_logits=logits.eval(feed_dict={image_holder: te_imgs_h2,label_holder: te_labels_h2,is_training: 'False'})
te_v2_logits=logits.eval(feed_dict={image_holder: te_imgs_v2,label_holder: te_labels_v2,is_training: 'False'})
te_hv2_logits=logits.eval(feed_dict={image_holder: te_imgs_hv2,label_holder: te_labels_hv2,is_training: 'False'})
te_3_logits=logits.eval(feed_dict={image_holder: te_imgs_3,label_holder: te_labels_3,is_training: 'False'})
te_h3_logits=logits.eval(feed_dict={image_holder: te_imgs_h3,label_holder: te_labels_h3,is_training: 'False'})
te_v3_logits=logits.eval(feed_dict={image_holder: te_imgs_v3,label_holder: te_labels_v3,is_training: 'False'})
te_hv3_logits=logits.eval(feed_dict={image_holder: te_imgs_hv3,label_holder: te_labels_hv3,is_training: 'False'})
te_4_logits=logits.eval(feed_dict={image_holder: te_imgs_4,label_holder: te_labels_4,is_training: 'False'})
te_h4_logits=logits.eval(feed_dict={image_holder: te_imgs_h4,label_holder: te_labels_h4,is_training: 'False'})
te_v4_logits=logits.eval(feed_dict={image_holder: te_imgs_v4,label_holder: te_labels_v4,is_training: 'False'})
te_hv4_logits=logits.eval(feed_dict={image_holder: te_imgs_hv4,label_holder: te_labels_hv4,is_training: 'False'})
te_5_logits=logits.eval(feed_dict={image_holder: te_imgs_5,label_holder: te_labels_5,is_training: 'False'})
te_h5_logits=logits.eval(feed_dict={image_holder: te_imgs_h5,label_holder: te_labels_h5,is_training: 'False'})
te_v5_logits=logits.eval(feed_dict={image_holder: te_imgs_v5,label_holder: te_labels_v5,is_training: 'False'})
te_hv5_logits=logits.eval(feed_dict={image_holder: te_imgs_hv5,label_holder: te_labels_hv5,is_training: 'False'})

te_logits =(te_1_logits+te_2_logits+te_3_logits+te_4_logits+te_5_logits+
    te_h1_logits+te_h2_logits+te_h3_logits+te_h4_logits+te_h5_logits+
    te_v1_logits+te_v2_logits+te_v3_logits+te_v4_logits+te_v5_logits+
    te_hv1_logits+te_hv2_logits+te_hv3_logits+te_hv4_logits+te_hv5_logits)/20
te_ture = sess.run(tf.nn.in_top_k(tf.convert_to_tensor(te_logits), y_test, 1))
print(te_ture)
te_true_count = np.sum(te_ture)
te_accuracy = te_true_count / y_test.shape[0]
print(te_accuracy)
coord.request_stop()
coord.join(threads)
sess.close()
print (time.strftime("%Y-%m-%d %H:%M:%S",time.localtime()))
# Out:
# 2018-09-14 18:21:54
# epoch--:1
# Best number of rounds: 1 , best_val_precision: 0.872247 ,best_train_accuracy: 0.675725
# epoch--:2
# Best number of rounds: 1 , best_val_precision: 0.872247 ,best_train_accuracy: 0.675725
# epoch--:3
# Best number of rounds: 1 , best_val_precision: 0.872247 ,best_train_accuracy: 0.675725
# epoch--:4
# Best number of rounds: 4 , best_val_precision: 0.929515 ,best_train_accuracy: 0.911232
# epoch--:5
# Best number of rounds: 5 , best_val_precision: 1.000000 ,best_train_accuracy: 0.976449
# epoch--:6
# Best number of rounds: 5 , best_val_precision: 1.000000 ,best_train_accuracy: 0.976449
# epoch--:7
# Best number of rounds: 5 , best_val_precision: 1.000000 ,best_train_accuracy: 0.976449
# 2018-09-14 18:22:15
# INFO:tensorflow:Restoring parameters from ./model_save/s/cnn1.ckpt
# ####################################
# 2018-09-14 18:22:15
# [ True  True]
# 1.0
# 2018-09-14 18:22:15

# %%
(te_1_logits+te_2_logits+te_3_logits+te_4_logits+te_5_logits+
te_h1_logits+te_h2_logits+te_h3_logits+te_h4_logits+te_h5_logits+
te_v1_logits+te_v2_logits+te_v3_logits+te_v4_logits+te_v5_logits+
te_hv1_logits+te_hv2_logits+te_hv3_logits+te_hv4_logits+te_hv5_logits)/20
# Out:
# array([[-34.94676  ,  32.030807 ],
#        [ 11.7872715, -10.191591 ]], dtype=float32)

# %%
te_2_logits
# Out:
# array([[-24.620667 ,  24.126604 ],
#        [  2.7126174,  -2.5133622]], dtype=float32)

# %%
te_1_logits
# Out:
# array([[-19.244764 ,  18.693659 ],
#        [  4.371067 ,  -3.4801967]], dtype=float32)

# %%
y_test
# Out:
# array([1, 0])
